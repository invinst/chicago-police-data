# %%
import pandas as pd
pd.options.display.max_columns = 999

# %%
ase = pd.read_csv('ase-units.csv.gz')
asu = pd.read_csv('all-sworn-units.csv.gz')

# %%
pase = pd.read_csv('problem_ase.csv')

# %%
pasu = pd.read_csv('problem_asu.csv')

# %%
not_same = list((set(pase['UID']) | set(pasu['UID'])) - (set(pase['UID']) & set(pasu['UID'])))

# %%
ref = pd.read_csv('officer-reference.csv.gz')
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3,10,11,12,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ref[ref['UID'].isin(not_same)]
# Out:
#        Appointed.Date  Birth.Year  Current.Age Current.Rank  Current.Star  \
# 26957      1971-02-22      1947.0          NaN          NaN           NaN
# 58951      1971-02-22      1947.0          NaN          NaN           NaN
# 90957      1971-02-22      1947.0          NaN          NaN           NaN
# 122610     1971-02-22         NaN         68.0          NaN           NaN
# 122615     1971-02-22         NaN         69.0          NaN           NaN
#
#         Current.Unit First.Name Gender Last.Name Middle.Initial  \
# 26957            NaN     ROBERT   MALE     SMITH              E
# 58951            NaN     ROBERT   MALE     SMITH              E
# 90957          284.0     ROBERT   MALE     SMITH              E
# 122610         602.0     ROBERT   MALE     SMITH            NaN
# 122615         284.0     ROBERT   MALE     SMITH            NaN
#
#        Middle.Initial2   Race Resignation.Date    Star1  Star10  Star2  Star3  \
# ...

# %%
ase_ids = ref[ref['UID'].isin(not_same)]['ase-units_ID'].dropna()

# %%
ase[ase['ase-units_ID'].isin(ase_ids)]
# Out:
#        Star8 Effective.Date   Unit  Star4    End.Date  Star6  Star7  Star5  \
# 97530    NaN     1971-02-22    5.0    NaN  1979-10-14    NaN    NaN    NaN
# 97531    NaN     1971-02-24  602.0    NaN         NaN    NaN    NaN    NaN
# 97544    NaN     1971-02-22   11.0    NaN  1981-12-09    NaN    NaN    NaN
# 97545    NaN     1981-12-10   25.0    NaN  1990-08-31    NaN    NaN    NaN
# 97546    NaN     1990-09-01  284.0    NaN         NaN    NaN    NaN    NaN
#
#       Appointed.Date Gender  Star10    Star1  Star9  Current.Age  Star3  \
# 97530     1971-02-22   MALE     NaN  20066.0    NaN         68.0    NaN
# 97531     1971-02-22   MALE     NaN  20066.0    NaN         68.0    NaN
# 97544     1971-02-22   MALE     NaN  15577.0    NaN         69.0    NaN
# 97545     1971-02-22   MALE     NaN  15577.0    NaN         69.0    NaN
# 97546     1971-02-22   MALE     NaN  15577.0    NaN         69.0    NaN
#
#         Race  Star2 Last.Name First.Name Middle.Initial Suffix.Name  \
# ...

# %%
asu_ids = ref[ref['UID'].isin(not_same)]['all-sworn-units_ID'].dropna()

# %%
asu[asu['all-sworn-units_ID'].isin(asu_ids)]
# Out:
#       Gender  Birth.Year Appointed.Date   Race  Start.Date    End.Date   Unit  \
# 98698   MALE      1947.0     1971-02-22  WHITE  1971-02-22  1979-10-14    5.0
# 98699   MALE      1947.0     1971-02-22  WHITE  1971-02-24         NaN  602.0
# 98700   MALE      1947.0     1971-02-22  WHITE  1971-02-22  1981-12-09   11.0
# 98701   MALE      1947.0     1971-02-22  WHITE  1981-12-10  1990-08-31   25.0
# 98702   MALE      1947.0     1971-02-22  WHITE  1990-09-01         NaN  284.0
#
#       Last.Name First.Name Middle.Initial Middle.Initial2 Suffix.Name  \
# 98698     SMITH     ROBERT              E             NaN         NaN
# 98699     SMITH     ROBERT              E             NaN         NaN
# 98700     SMITH     ROBERT              E             NaN         NaN
# 98701     SMITH     ROBERT              E             NaN         NaN
# 98702     SMITH     ROBERT              E             NaN         NaN
#
#        all-sworn-units_ID
# 98698               25879
# ...
