# %%
import pandas as pd
from assign_unique_ids_functions import *
from merge_functions import *

# %%
profiles = pd.read_csv('../input/officer-profiles.csv.gz')
reference = pd.read_csv('../input/officer-reference.csv.gz')

# %%
acc = pd.read_csv('../input/accused_demographics.csv.gz')
acc.head()
# Out:
#    accused_ID First.Name Last.Name Suffix.Name Appointed.Date  Birth.Year  \
# 0       15644    WILLIAM    BARRON         NaN     1978-02-27        1949
# 1        8600   KIMBERLY  C0NNOLLY         NaN     1990-07-30        1965
# 2        6949       JOHN     KEENE         NaN     1999-03-08        1968
# 3       13744      SCOTT    SLAVIN         NaN     1991-11-18        1965
# 4         917    ANTONIO  MARTINEZ         NaN     1996-11-04        1971
#
#    Gender   Race Middle.Initial  Current.Unit  Current.Star
# 0    MALE  WHITE            NaN            18          -999
# 1  FEMALE  BLACK            NaN            55         11026
# 2    MALE  WHITE            NaN           153          -999
# 3    MALE  WHITE            NaN           145           807
# 4    MALE  WHITE            NaN           701          -999

# %%
atr_dict = append_to_reference(sub_df=acc,
                               profile_df = profiles,
                               ref_df = reference,
                               no_match_cols=["Last.Name"],
                              return_unmatched=True)
# Out:
# 16018 Total Merged. 50.03% of DF1 and 99.98% of DF2 Merged.
# 15998 Unmerged in DF1. 49.97% Unmerged.
# 3 Unmerged in DF2. 0.01% Unmerged.

# %%
atr_dict.keys()
# Out:
# dict_keys(['ref', 'UM1', 'UM2', 'MR', 'ML'])

# %%
um2 = atr_dict['UM2']
um2
# Out:
#        accused_ID First.Name    Last.Name Suffix.Name Appointed.Date  \
# 7768        14393     SUSANA  LACASACALIZ         NaN     1999-03-08
# 9246         9231       LUIS    CONTRERAS         NaN     2000-09-11
# 15030        5688      JAMEL        JUDEH         NaN     2012-10-05
#
#        Birth.Year  Gender      Race Middle.Initial  Current.Unit  F4FN  F4LN
# 7768         1964  FEMALE     WHITE            NaN           376  SUSA  LACA
# 9246         1968    MALE     WHITE            NaN           376  LUIS  CONT
# 15030        1983    MALE  HISPANIC            NaN            44  JAME  JUDE

# %%
um1 = atr_dict['UM1']

# %%
ref2 = atr_dict['ref']

# %%
prof2 = aggregate_data(ref2, 'UID', mode_cols = listdiff(ref2.columns, ['UID']))
# Out:
# Mode Aggregating Current.Unit column
# Mode Aggregating Birth.Year column
# Mode Aggregating First.Name column
# /Users/invinst/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Mode Aggregating Race column
# Mode Aggregating Last.Name column

# %%
prof2.tail()
# Out:
#          UID  Current.Unit  Star8  Birth.Year  Star6  Current.Age First.Name  \
# 32014  32015          50.0 -999.0         NaN -999.0         55.0    MICHAEL
# 32015  32016         602.0 -999.0         NaN -999.0         68.0     ROBERT
# 32016  32017         376.0    NaN      1964.0    NaN          NaN     SUSANA
# 32017  32018         376.0    NaN      1968.0    NaN          NaN       LUIS
# 32018  32019          44.0    NaN      1983.0    NaN          NaN      JAMEL
#
#       Appointed.Date accused_ID  Star9     ...      Middle.Initial  \
# 32014     1985-07-01        NaN -999.0     ...                 NaN
# 32015     1971-02-22        NaN -999.0     ...                 NaN
# 32016     1999-03-08      14393    NaN     ...                 NaN
# 32017     2000-09-11       9231    NaN     ...                 NaN
# 32018     2012-10-05       5688    NaN     ...                 NaN
#
#          Last.Name  Gender  unit_history_ID  Current.Star    Star1  Star5  \
# 32014         SIMI    MALE          26242.0           NaN  17493.0 -999.0
# 32015        SMITH    MALE          26674.0           NaN  20066.0 -999.0
# 32016  LACASACALIZ  FEMALE              NaN        -999.0      NaN    NaN
# 32017    CONTRERAS    MALE              NaN        -999.0      NaN    NaN
# 32018        JUDEH    MALE              NaN        -999.0      NaN    NaN
#
#       Star10  Star2 Suffix.Name
# 32014 -999.0 -999.0         NaN
# 32015 -999.0 -999.0         NaN
# 32016    NaN    NaN         NaN
# 32017    NaN    NaN         NaN
# 32018    NaN    NaN         NaN
#
# [5 rows x 27 columns]

# %%
wit = pd.read_csv('../input/witnesses_demographics.csv.gz')

# %%
wit.head()
# Out:
#    witnesses_ID First.Name     Last.Name Middle.Initial Suffix.Name  \
# 0          7529        NED  DOLCIMASCOLO            NaN         NaN
# 1         10821     YVONNE        BRYANT            NaN         NaN
# 2          8991      RONDY       CARROLL            NaN         NaN
# 3          2451      DIEGO      CASTILLO            NaN         NaN
# 4          3507       GINA     RODIRGUEZ            NaN         NaN
#
#   Appointed.Date  Birth.Year  Current.Star
# 0     1972-10-23        1945          -999
# 1     1998-08-31        1956          -999
# 2     1997-08-04        1973          -999
# 3     1994-07-05        1963          7499
# 4     1990-03-26        1964         20045

# %%
atr_dict2 = append_to_reference(sub_df=wit,
                               profile_df = prof2,
                               ref_df = ref2,
                              return_unmatched=True,
                               print_merging=True,
                               no_match_cols=["Last.Name", "Current.Star"])
# Out:
# 1896 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Current.Star'] columns
# 2 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN', 'Current.Star'] columns
# 2 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name', 'Current.Star'] columns
# 1 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Appointed.Date', 'Last.Name', 'First.Name', 'Current.Star'] columns
# 8363 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Current.Star'] columns
# 5 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN', 'Current.Star'] columns
# 18 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name', 'Current.Star'] columns
# 32 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Current.Star'] columns
# 1 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4FN', 'Current.Star'] columns
# 7 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Appointed.Date', 'First.Name', 'Current.Star'] columns
# 5 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Appointed.Date', 'F4FN', 'Current.Star'] columns
# 161 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Current.Star'] columns
# 1 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'F4FN', 'Current.Star'] columns
# 38 Matches on
# ['Suffix.Name', 'Appointed.Date', 'First.Name', 'Current.Star'] columns
# 6 Matches on
# ['Suffix.Name', 'Appointed.Date', 'F4FN', 'Current.Star'] columns
# 2 Matches on
# ['Middle.Initial', 'Appointed.Date', 'First.Name', 'Current.Star'] columns
# 159 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 1 Matches on
# ['Suffix.Name', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name'] columns
# 574 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 4 Matches on
# ['Suffix.Name', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name'] columns
# 1 Matches on
# ['Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 11279 Total Merged. 35.23% of DF1 and 97.55% of DF2 Merged.
# 20740 Unmerged in DF1. 64.77% Unmerged.
# 283 Unmerged in DF2. 0.88% Unmerged.

# %%
um1 = atr_dict2['UM1']
um2 = atr_dict2['UM2']

# %%
um2.tail()
# Out:
#        witnesses_ID First.Name    Last.Name Middle.Initial Suffix.Name  \
# 10480          9326      SHANA           BA            NaN         NaN
# 10565          7477     MYRIAN  SWIATKOWSKI            NaN         NaN
# 10577           755    BARBARA       VALDEZ            NaN         NaN
# 10581          3368     GEORGE  BUKOWSKIBUS            NaN         NaN
# 10909          1739    DAKEITA       MILLER            NaN         NaN
#
#       Appointed.Date  Birth.Year  Current.Star  F4FN  F4LN
# 10480     1995-08-07        1970         10090  SHAN    BA
# 10565     2001-03-26        1974          4159  MYRI  SWIA
# 10577     1995-01-03        1958         21142  BARB  VALD
# 10581     1996-12-02        1966         11982  GEOR  BUKO
# 10909     2013-06-17        1979             0  DAKE  MILL

# %%
prof2[prof2['Last.Name']=='VALDEZ'][["First.Name", "Last.Name", "Appointed.Date", "Birth.Year"]]
# Out:
#         First.Name Last.Name Appointed.Date  Birth.Year
# 29430        CESAR    VALDEZ     2016-06-27      1985.0
# 29431  CHRISTOPHER    VALDEZ     2016-08-29      1992.0
# 29432         JOHN    VALDEZ     1982-07-19      1956.0
# 29433      OSVALDO    VALDEZ     1991-12-16      1970.0
# 29434        RUBEN    VALDEZ     2004-09-27      1971.0
# 29435       SERGIO    VALDEZ     2002-02-25      1978.0
# 29436     REYNALDO    VALDEZ     1997-03-17      1969.0

# %%
#ref3 = atr_dict2['ref']
ref3 = atr_dict['ref']

# %%
prof3 = aggregate_data(ref3, 'UID', mode_cols = listdiff(ref3.columns, ['UID']))
# Out:
# Mode Aggregating Current.Unit column
# Mode Aggregating Birth.Year column
# Mode Aggregating First.Name column
# /Users/invinst/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Mode Aggregating Race column
# Mode Aggregating Last.Name column

# %%
inv = pd.read_csv('../input/investigators_demographics.csv.gz')

# %%
inv[inv['First.Name'].str.contains('TERE')][inv['Appointed.Date'] == '1986-09-08']
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      investigators_ID First.Name Last.Name Appointed.Date
# 375               428     TERESE     FLYNN     1986-09-08

# %%
atr_dict3 = append_to_reference(sub_df=inv,
                               profile_df = prof3,
                               ref_df = ref3,
                              return_unmatched=True,
                                no_match_cols=['Last.Name'],
                               custom_matches = [["First.Name", "Appointed.Date"]])
# Out:
# 2964 Total Merged. 9.26% of DF1 and 99.66% of DF2 Merged.
# 29055 Unmerged in DF1. 90.74% Unmerged.
# 10 Unmerged in DF2. 0.03% Unmerged.

# %%
um2 = atr_dict3['UM2'].sort_values('investigators_ID')
um2
# Out:
#       investigators_ID First.Name  Last.Name Appointed.Date  F4FN  F4LN
# 481                536      JAMES   ROUSSELL     2014-04-16  JAME  ROUS
# 610                666     JOSEPH     MURPHY     2006-12-01  JOSE  MURP
# 794                859     GEORGE      JONES     1975-05-16  GEOR  JONE
# 1276              1370   TERRENCE    FOGARTY     1995-12-18  TERR  FOGA
# 1349              1452    MICHAEL  DOUGHERTY     1994-09-06  MICH  DOUG
# 1428              1535     ROBERT      ROMAN     2005-03-01  ROBE  ROMA
# 1572              1690     MARVIN      SHEAR     2004-07-16  MARV  SHEA
# 1735              1882     ROBERT     KLIMAS     2008-08-04  ROBE  KLIM
# 2482              2692      KEVIN    CONNORS     1999-09-13  KEVI  CONN
# 2518              2728      KEVIN      SMITH     1999-05-10  KEVI  SMIT

# %%
um1 = atr_dict3['UM1']

# %%
um1[um1['UID'] == 8897]
# Out:
# Empty DataFrame
# Columns: [UID, First.Name, Appointed.Date, Last.Name, F4FN, F4LN]
# Index: []

# %%
atr_dict3['ref'][atr_dict3['ref']['UID'] == 8897]
# Out:
#        Appointed.Date  Birth.Year  Current.Age  Current.Star  Current.Unit  \
# 8896       1986-09-08      1958.0          NaN           NaN           NaN
# 40902      1986-09-08      1958.0          NaN           NaN          16.0
# 72282      1986-09-08      1958.0          NaN           NaN           NaN
# 104111     1986-09-08         NaN         57.0           NaN          16.0
# 130891     1986-09-08      1958.0          NaN        -999.0          16.0
# 143930     1986-09-08         NaN          NaN           NaN           NaN
#
#        First.Name  Gender Last.Name Middle.Initial   Race       ...         \
# 8896       TERESE  FEMALE     FLYNN              J  WHITE       ...
# 40902      TERESE  FEMALE     FLYNN              J  WHITE       ...
# 72282      TERESE  FEMALE   FANNING              J  WHITE       ...
# 104111     TERESE  FEMALE   FANNING            NaN  WHITE       ...
# 130891     TERESE  FEMALE     FLYNN            NaN  WHITE       ...
# 143930     TERESE     NaN     FLYNN            NaN    NaN       ...
#
#         Star8  Star9  Suffix.Name   UID  accused_ID  all_members_ID  \
# 8896      NaN    NaN          NaN  8897         NaN             NaN
# 40902     NaN    NaN          NaN  8897         NaN             NaN
# 72282     NaN    NaN          NaN  8897         NaN         28521.0
# 104111 -999.0 -999.0          NaN  8897         NaN             NaN
# 130891    NaN    NaN          NaN  8897       14516             NaN
# 143930    NaN    NaN          NaN  8897         NaN             NaN
#
#         all_sworn_ID  all_sworn_units_ID  investigators_ID  unit_history_ID
# 8896         28598.0                 NaN               NaN              NaN
# 40902            NaN             28598.0               NaN              NaN
# 72282            NaN                 NaN               NaN              NaN
# 104111           NaN                 NaN               NaN           8175.0
# 130891           NaN                 NaN               NaN              NaN
# 143930           NaN                 NaN               428              NaN
#
# [6 rows x 28 columns]

# %%
prof3[prof3['First.Name']=='TERESE'][["First.Name", "Last.Name", "Appointed.Date", "UID"]]
# Out:
#       First.Name Last.Name Appointed.Date    UID
# 8896      TERESE   FANNING     1986-09-08   8897
# 27273     TERESE      SOTO     2000-01-24  27274

# %%
invf = pd.read_csv('../input/investigators.csv.gz')

# %%
invf[invf['investigators_ID'].isin(um2['investigators_ID'])].sort_values('investigators_ID')
# Out:
#         investigators_ID     CRID  Assignment          Current.Rank
# 1041                 536   260155       115.0                 CHIEF
# 20224                536   279588       115.0                 CHIEF
# 51465                536   310400       115.0                 CHIEF
# 6616                 536   265851       115.0                 CHIEF
# 73224                536   310400       115.0                 CHIEF
# 11582                666   270890       177.0             COMMANDER
# 15951                666   275288       177.0             COMMANDER
# 1508                 666   260638       177.0             COMMANDER
# 6923                 859   266167         7.0  LIEUTENANT OF POLICE
# 11987                859   271300         7.0  LIEUTENANT OF POLICE
# 25072                859   284456         7.0  LIEUTENANT OF POLICE
# 2456                 859   261620         7.0  LIEUTENANT OF POLICE
# 17961                859   277312         7.0  LIEUTENANT OF POLICE
# 16903               1370   276242       167.0             COMMANDER
# 38943               1370   298262       167.0             COMMANDER
# 19863               1370   279226       167.0             COMMANDER
# 35667               1370   294941       167.0             COMMANDER
# 38854               1370   298171       167.0             COMMANDER
# 31123               1370   290307       167.0             COMMANDER
# 7560                1370   266817       167.0             COMMANDER
# 31513               1452   290703        22.0    SERGEANT OF POLICE
# 35802               1452   295079        22.0    SERGEANT OF POLICE
# 76004               1452   313404        22.0    SERGEANT OF POLICE
# 77198               1452   314667        22.0    SERGEANT OF POLICE
# 41689               1452   301050        22.0    SERGEANT OF POLICE
# 42843               1452   302210        22.0    SERGEANT OF POLICE
# 47030               1452   306433        22.0    SERGEANT OF POLICE
# 79473               1452  1001613        22.0    SERGEANT OF POLICE
# 50954               1452   310381        22.0    SERGEANT OF POLICE
# 85476               1452  1009789        22.0    SERGEANT OF POLICE
# ...                  ...      ...         ...                   ...
# 107401              1882  1043317       121.0             COMMANDER
# 107341              1882  1043202       121.0             COMMANDER
# 107307              1882  1043142       121.0             COMMANDER
# 107419              1882  1043351       121.0             COMMANDER
# 107426              1882  1043362       121.0             COMMANDER
# 107446              1882  1043393       121.0             COMMANDER
# 107229              1882  1042997       121.0             COMMANDER
# 107416              1882  1043348       121.0             COMMANDER
# 107418              1882  1043350       121.0             COMMANDER
# 107228              1882  1042994       121.0             COMMANDER
# 107207              1882  1042961       121.0             COMMANDER
# 107206              1882  1042960       121.0             COMMANDER
# 107053              1882  1042710       121.0             COMMANDER
# 107499              1882  1043488       121.0             COMMANDER
# 106938              1882  1042507       121.0             COMMANDER
# 106926              1882  1042488       121.0             COMMANDER
# 106644              1882  1042003       121.0             COMMANDER
# 113784              2692  1053761       211.0    SERGEANT OF POLICE
# 114276              2692  1054676       211.0    SERGEANT OF POLICE
# 130092              2692  1080419       211.0    SERGEANT OF POLICE
# 116251              2692  1058170       211.0    SERGEANT OF POLICE
# 124071              2692  1071281       211.0    SERGEANT OF POLICE
# 129702              2692  1079768       211.0    SERGEANT OF POLICE
# 113556              2692  1053399       211.0    SERGEANT OF POLICE
# 122067              2692  1068094       211.0    SERGEANT OF POLICE
# 97714               2692  1027088       211.0    SERGEANT OF POLICE
# 102414              2728  1034738       376.0        POLICE OFFICER
# 100558              2728  1031763       376.0        POLICE OFFICER
# 105562              2728  1040059       376.0        POLICE OFFICER
# 103712              2728  1037021       376.0        POLICE OFFICER
#
# [1600 rows x 4 columns]

# %%
invf['Current.Rank'][~invf['Current.Rank'].str.contains('IPRA')].value_counts()
# Out:
# SERGEANT OF POLICE             55722
# LIEUTENANT OF POLICE           13085
# POLICE AGENT                    9789
# POLICE OFFICER                  4399
# COMMANDER                       3174
# CAPTAIN OF POLICE               1913
# PO AS DETECTIVE                 1294
# DEP CHIEF                        459
# INTAKE AIDE                      354
# COOR /INVESTIGATIONS             336
# SUPV POLICE COMM                 332
# CHIEF                            307
# SUPERVISING INVESTIGATOR         296
# PO ASGN EVID. TECHNI             158
# PO LEGAL OFF 2                   109
# FIRST DEPUTY SUPT.                47
# DEPUTY SUPT.                      38
# MGR DATA ENTRY &OPR               38
# SUPT OF POLICE                    27
# DIR RESEARCH/PLANING              21
# POLICE ADMINISTRATIVE CLERK       19
# SUPV.CROSSING GUARD               18
# TRAINING OFFICER                  16
# SERGEANT PER ARBITRA              15
# CROSSING GUARD COOR               14
# DEPUTY CHIEF ADMINISTRATOR        14
# CROSSING GUARD                    13
# ASSISTANT SUPERINTENDENT          10
# ASST SUPV POLICE REC               7
# COMM OF GENL SUPPORT               7
#                                ...
# COMMUNITY ORGANIZER                2
# PO/MOUNTED PAT OFF.                1
# ASSOCIATE STAFF ATTORNEY           1
# DIR OF INFORM SYST                 1
# CUSTODIAL WORKER                   1
# SUPVR HEALTH NURSE                 1
# TRAFFIC  CONTROL AIDE              1
# FOREMAN OF ELEC MECH               1
# PO/MARINE OFFICER                  1
# CHIEF DATA BASE ANAL               1
# MGR VEH MAINTANCE                  1
# CRIMINALIST 2                      1
# PO ASSG CANINE HANDL               1
# GAR ATT IN CHARGE                  1
# POLICE COMM OPER 2                 1
# MGR VEHICLE ADJ                    1
# SR PROG/ANALY                      1
# MGR STSTEMS DEV                    1
# MOTOR TRUCK DRIVER                 1
# F/P TECH 3                         1
# ADMIN SERV OFF II                  1
# ADMIN ASSIST 2                     1
# ASST MGR FINANCE                   1
# DIR POLICE FINANCE                 1
# RECORD CLK                         1
# POL FORENSIC INV III               1
# HEAD CASHIER                       1
# SPECIAL ASSIST                     1
# STAFF ASSISTANT                    1
# INVESTIGATOR                       1
# Name: Current.Rank, Length: 87, dtype: int64

# %%
invf['Current.Rank'][~invf['Current.Rank'].str.contains('IPRA') & invf['Current.Rank'].str.contains('PO')].unique().tolist()
# Out:
# ['LIEUTENANT OF POLICE',
#  'SERGEANT OF POLICE',
#  'CAPTAIN OF POLICE',
#  'POLICE OFFICER',
#  'POLICE AGENT',
#  'PO AS DETECTIVE',
#  'SUPT OF POLICE',
#  'PO LEGAL OFF 2',
#  'SUPV POLICE COMM',
#  'POL FORENSIC INV II',
#  'POLICE ADMINISTRATIVE CLERK',
#  'PO/MOUNTED PAT OFF.',
#  'PO/FIELD TRNING OFF',
#  'PO ASGN EVID. TECHNI',
#  'MGR POL SYSTEMS SUPP',
#  'DIR POLICE FINANCE',
#  'POLICE COMM OPER 2',
#  'MGR OF NETWORK SUPPO',
#  'PO/MARINE OFFICER',
#  'MANAGER OF POLICE RECORDS',
#  'PO ASSG CANINE HANDL',
#  'ASST SUPV POLICE REC',
#  'COMM OF GENL SUPPORT',
#  'POL FORENSIC INV III',
#  'MGR POLICE PERSONNEL',
#  'POLICE TECHNICIAN',
#  'POLICE AIDE']

# %%
ref4 = atr_dict3['ref']
prof4 = aggregate_data(ref4, 'UID', mode_cols = listdiff(ref4.columns, ['UID']))
# Out:
# Mode Aggregating Current.Unit column
# Mode Aggregating Birth.Year column
# Mode Aggregating First.Name column
# /Users/invinst/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Mode Aggregating Race column
# Mode Aggregating Last.Name column

# %%
trro = pd.read_csv('../input/trr-officers_demographics.csv.gz')

# %%
atr_dict4 = append_to_reference(sub_df=trro,
                               profile_df = prof4,
                               ref_df = ref4,
                              return_unmatched=True,
                               expand_stars=True,
                            no_match_cols=["Last.Name", "Current.Star"])
# Out:
# 10796 Total Merged. 33.71% of DF1 and 99.98% of DF2 Merged.
# 21233 Unmerged in DF1. 66.29% Unmerged.
# 2 Unmerged in DF2. 0.01% Unmerged.

# %%
um2 = atr_dict4['UM2']
um1 = atr_dict4['UM1']
um2
# Out:
#       trr_officers_ID First.Name Last.Name Suffix.Name Appointed.Date  Gender  \
# 3968             3995     ALBERT   KRUEGER         NaN     2007-03-16    MALE
# 4091             4121     SHARON    GALATI         NaN     1981-03-02  FEMALE
#
#        Race  Current.Star  F4FN  F4LN  Star1  Star2  Star3  Star4  Star5  \
# 3968  WHITE            18  ALBE  KRUE     18     18     18     18     18
# 4091  WHITE         30109  SHAR  GALA  30109  30109  30109  30109  30109
#
#       Star6  Star7  Star8  Star9  Star10
# 3968     18     18     18     18      18
# 4091  30109  30109  30109  30109   30109

# %%
ref5 = atr_dict4['ref']
prof5 = aggregate_data(ref5, 'UID', mode_cols = listdiff(ref5.columns, ['UID']))
# Out:
# Mode Aggregating Current.Unit column
# Mode Aggregating Birth.Year column
# Mode Aggregating First.Name column
# /Users/invinst/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Mode Aggregating Race column
# Mode Aggregating Last.Name column
# Mode Aggregating Current.Star column

# %%
prof5.tail(20)
# Out:
#          UID  Current.Unit  Star8  Birth.Year  Star6  Current.Age First.Name  \
# 32011  32012          25.0 -999.0         NaN -999.0         64.0      JAMES
# 32012  32013          18.0 -999.0         NaN -999.0         55.0      JAMES
# 32013  32014          44.0 -999.0         NaN -999.0         32.0      PETER
# 32014  32015          50.0 -999.0         NaN -999.0         55.0    MICHAEL
# 32015  32016         602.0 -999.0         NaN -999.0         68.0     ROBERT
# 32016  32017         376.0    NaN      1964.0    NaN          NaN     SUSANA
# 32017  32018         376.0    NaN      1968.0    NaN          NaN       LUIS
# 32018  32019          44.0    NaN      1983.0    NaN          NaN      JAMEL
# 32019  32020           NaN    NaN         NaN    NaN          NaN      JAMES
# 32020  32021           NaN    NaN         NaN    NaN          NaN     JOSEPH
# 32021  32022           NaN    NaN         NaN    NaN          NaN     GEORGE
# 32022  32023           NaN    NaN         NaN    NaN          NaN   TERRENCE
# 32023  32024           NaN    NaN         NaN    NaN          NaN    MICHAEL
# 32024  32025           NaN    NaN         NaN    NaN          NaN     ROBERT
# 32025  32026           NaN    NaN         NaN    NaN          NaN     MARVIN
# 32026  32027           NaN    NaN         NaN    NaN          NaN     ROBERT
# 32027  32028           NaN    NaN         NaN    NaN          NaN      KEVIN
# 32028  32029           NaN    NaN         NaN    NaN          NaN      KEVIN
# 32029  32030           NaN    NaN         NaN    NaN          NaN     ALBERT
# 32030  32031           NaN    NaN         NaN    NaN          NaN     SHARON
#
#       Appointed.Date accused_ID  Star9       ...           Last.Name  Gender  \
# 32011     1978-12-11        NaN -999.0       ...               JOYCE    MALE
# 32012     1985-03-04        NaN -999.0       ...              MARTIN    MALE
# 32013     2006-09-25        NaN -999.0       ...               PALKA    MALE
# 32014     1985-07-01        NaN -999.0       ...                SIMI    MALE
# 32015     1971-02-22        NaN -999.0       ...               SMITH    MALE
# 32016     1999-03-08      14393    NaN       ...         LACASACALIZ  FEMALE
# 32017     2000-09-11       9231    NaN       ...           CONTRERAS    MALE
# 32018     2012-10-05       5688    NaN       ...               JUDEH    MALE
# 32019     2014-04-16        NaN    NaN       ...            ROUSSELL     NaN
# 32020     2006-12-01        NaN    NaN       ...              MURPHY     NaN
# 32021     1975-05-16        NaN    NaN       ...               JONES     NaN
# 32022     1995-12-18        NaN    NaN       ...             FOGARTY     NaN
# 32023     1994-09-06        NaN    NaN       ...           DOUGHERTY     NaN
# 32024     2005-03-01        NaN    NaN       ...               ROMAN     NaN
# 32025     2004-07-16        NaN    NaN       ...               SHEAR     NaN
# 32026     2008-08-04        NaN    NaN       ...              KLIMAS     NaN
# 32027     1999-09-13        NaN    NaN       ...             CONNORS     NaN
# 32028     1999-05-10        NaN    NaN       ...               SMITH     NaN
# 32029     2007-03-16        NaN    NaN       ...             KRUEGER    MALE
# 32030     1981-03-02        NaN    NaN       ...              GALATI  FEMALE
#
#        unit_history_ID  Current.Star    Star1  Star5  Star10  Star2  \
# 32011          13804.0           NaN   7089.0 -999.0  -999.0 -999.0
# 32012          17434.0       17311.0  17311.0 -999.0  -999.0 -999.0
# 32013          21563.0           NaN   -999.0 -999.0  -999.0 -999.0
# 32014          26242.0           NaN  17493.0 -999.0  -999.0 -999.0
# 32015          26674.0           NaN  20066.0 -999.0  -999.0 -999.0
# 32016              NaN        -999.0      NaN    NaN     NaN    NaN
# 32017              NaN        -999.0      NaN    NaN     NaN    NaN
# 32018              NaN        -999.0      NaN    NaN     NaN    NaN
# 32019              NaN           NaN      NaN    NaN     NaN    NaN
# 32020              NaN           NaN      NaN    NaN     NaN    NaN
# 32021              NaN           NaN      NaN    NaN     NaN    NaN
# 32022              NaN           NaN      NaN    NaN     NaN    NaN
# 32023              NaN           NaN      NaN    NaN     NaN    NaN
# 32024              NaN           NaN      NaN    NaN     NaN    NaN
# 32025              NaN           NaN      NaN    NaN     NaN    NaN
# 32026              NaN           NaN      NaN    NaN     NaN    NaN
# 32027              NaN           NaN      NaN    NaN     NaN    NaN
# 32028              NaN           NaN      NaN    NaN     NaN    NaN
# 32029              NaN          18.0      NaN    NaN     NaN    NaN
# 32030              NaN       30109.0      NaN    NaN     NaN    NaN
#
#       Suffix.Name investigators_ID
# 32011         NaN              NaN
# 32012          IV              NaN
# 32013         NaN              NaN
# 32014         NaN              NaN
# 32015         NaN              NaN
# 32016         NaN              NaN
# 32017         NaN              NaN
# 32018         NaN              NaN
# 32019         NaN              536
# 32020         NaN              666
# 32021         NaN              859
# 32022         NaN             1370
# 32023         NaN             1452
# 32024         NaN             1535
# 32025         NaN             1690
# 32026         NaN             1882
# 32027         NaN             2692
# 32028         NaN             2728
# 32029         NaN              NaN
# 32030         NaN              NaN
#
# [20 rows x 29 columns]

# %%
trrs = pd.read_csv('../input/trr-statuses_demographics.csv.gz')

# %%
trrs.head()
# Out:
#    trr_statuses_ID First.Name  Last.Name  Middle.Initial Suffix.Name  \
# 0                1     ANGELO  VELAZQUEZ             NaN         NaN
# 1                2       JUAN       RIOS             NaN         NaN
# 2                3    RICHARD      ELMER             NaN         NaN
# 3                4      ANDRE      REYES             NaN         NaN
# 4                5      MARIO      LIMON             NaN         NaN
#
#   Appointed.Date Gender      Race  Current.Star
# 0     1994-01-18   MALE  HISPANIC          3646
# 1     1991-01-30   MALE  HISPANIC           738
# 2     1973-10-22   MALE     WHITE            27
# 3     1985-11-18   MALE  HISPANIC         17714
# 4     2000-09-11   MALE  HISPANIC         14214

# %%
atr_dict5 = append_to_reference(sub_df=trrs,
                               profile_df = prof5,
                               ref_df = ref5,
                                no_match_cols=['Last.Name', 'Current.Star'],
                                expand_stars=True,
                              return_unmatched=True)
# Out:
# 11470 Total Merged. 35.81% of DF1 and 99.98% of DF2 Merged.
# 20561 Unmerged in DF1. 64.19% Unmerged.
# 2 Unmerged in DF2. 0.01% Unmerged.

# %%
um2 = atr_dict5['UM2']
um1 = atr_dict5['UM1']

# %%
um2
# Out:
#       trr_statuses_ID First.Name Last.Name Suffix.Name Appointed.Date Gender  \
# 2548             2575     DONALD    ONEILL         NaN     1982-11-29   MALE
# 3325             3360    MICHAEL    CRONIN         NaN     2007-02-01   MALE
#
#        Race  Current.Star  F4FN  F4LN  Star1  Star2  Star3  Star4  Star5  \
# 2548  WHITE           109  DONA  ONEI    109    109    109    109    109
# 3325  WHITE         60090  MICH  CRON  60090  60090  60090  60090  60090
#
#       Star6  Star7  Star8  Star9  Star10
# 2548    109    109    109    109     109
# 3325  60090  60090  60090  60090   60090

# %%
prof5[prof5['First.Name'] == 'MICHAEL'][prof5['Last.Name']=='CRONIN']
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        UID  Current.Unit  Star8  Birth.Year  Star6  Current.Age First.Name  \
# 5760  5761           5.0 -999.0      1962.0 -999.0         53.0    MICHAEL
#
#      Appointed.Date accused_ID  Star9       ...         Last.Name Gender  \
# 5760     1994-05-02      10320 -999.0       ...            CRONIN   MALE
#
#       unit_history_ID  Current.Star   Star1  Star5  Star10   Star2  \
# 5760           5686.0        5025.0  7202.0 -999.0  -999.0  5025.0
#
#      Suffix.Name investigators_ID
# 5760         NaN              NaN
#
# [1 rows x 29 columns]

# %%
ref6 = atr_dict5['ref']
prof6 = aggregate_data(ref6, 'UID', mode_cols = listdiff(ref6.columns, ['UID']))
# Out:
# Mode Aggregating Current.Unit column
# Mode Aggregating Birth.Year column
# Mode Aggregating First.Name column
# /Users/invinst/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# Mode Aggregating Race column
# Mode Aggregating Last.Name column
# Mode Aggregating Current.Star column

# %%
prof6.tail()
# Out:
#          UID  Current.Unit  Star8  Birth.Year  Star6  Current.Age First.Name  \
# 32028  32029           NaN    NaN         NaN    NaN          NaN      KEVIN
# 32029  32030           NaN    NaN         NaN    NaN          NaN     ALBERT
# 32030  32031           NaN    NaN         NaN    NaN          NaN     SHARON
# 32031  32032           NaN    NaN         NaN    NaN          NaN     DONALD
# 32032  32033           NaN    NaN         NaN    NaN          NaN    MICHAEL
#
#       Appointed.Date accused_ID  Star9       ...         trr_statuses_ID  \
# 32028     1999-05-10        NaN    NaN       ...                     NaN
# 32029     2007-03-16        NaN    NaN       ...                    4655
# 32030     1981-03-02        NaN    NaN       ...                     NaN
# 32031     1982-11-29        NaN    NaN       ...                    2575
# 32032     2007-02-01        NaN    NaN       ...                    3360
#
#        Gender  unit_history_ID  Current.Star Star1  Star5  Star10  Star2  \
# 32028     NaN              NaN           NaN   NaN    NaN     NaN    NaN
# 32029    MALE              NaN          18.0   NaN    NaN     NaN    NaN
# 32030  FEMALE              NaN       30109.0   NaN    NaN     NaN    NaN
# 32031    MALE              NaN         109.0   NaN    NaN     NaN    NaN
# 32032    MALE              NaN       60090.0   NaN    NaN     NaN    NaN
#
#       Suffix.Name investigators_ID
# 32028         NaN             2728
# 32029         NaN              NaN
# 32030         NaN              NaN
# 32031         NaN              NaN
# 32032         NaN              NaN
#
# [5 rows x 30 columns]

# %%
awd = pd.read_csv('../input/awards_demographics.csv.gz')
awdf = pd.read_csv('../input/awards.csv.gz')

# %%
tdict = {'sub_df':awd,'profile_df': prof6,
                               'ref_df' :ref6,
                                'no_match_cols': ["Last.Name", "Current.Star"],
                                'expand_stars':True,
                              'return_unmatched':True}
atr_dict6 = append_to_reference(**tdict)
# Out:
# 21372 Total Merged. 66.72% of DF1 and 99.5% of DF2 Merged.
# 10661 Unmerged in DF1. 33.28% Unmerged.
# 107 Unmerged in DF2. 0.33% Unmerged.

# %%
um2 = atr_dict6['UM2']
um1 = atr_dict6['UM1']

# %%
um2.sort_values(["Last.Name", "First.Name"]).head()
# Out:
#       awards_ID First.Name   Last.Name Appointed.Date  Gender  Birth.Year  \
# 89         4027      CRAIG       ADAMS     2017-03-16    MALE        1989
# 256       22739     SHEEMA         ALI     2016-10-31  FEMALE        1986
# 537        2730     CARLOS    APARICIO     2006-07-16    MALE        1986
# 591        4021   COURTNEY   ARMSTRONG     2016-10-31  FEMALE        1991
# 1028       8903     HECTOR  BASAVESOTO     2017-01-17    MALE        1993
#
#       Current.Star  F4FN  F4LN  Star1  Star2  Star3  Star4  Star5  Star6  \
# 89            -999  CRAI  ADAM   -999   -999   -999   -999   -999   -999
# 256          17354  SHEE   ALI  17354  17354  17354  17354  17354  17354
# 537           -999  CARL  APAR   -999   -999   -999   -999   -999   -999
# 591          14440  COUR  ARMS  14440  14440  14440  14440  14440  14440
# 1028          -999  HECT  BASA   -999   -999   -999   -999   -999   -999
#
#       Star7  Star8  Star9  Star10
# 89     -999   -999   -999    -999
# 256   17354  17354  17354   17354
# 537    -999   -999   -999    -999
# 591   14440  14440  14440   14440
# 1028   -999   -999   -999    -999

# %%
awdf[awdf['awards_ID'].isin(um2['awards_ID'])]['Rank'].value_counts()
# Out:
# 9161-POLICE OFFICER         174
# 9106-POLICE CADET            80
# 9164-PO/FIELD TRNING OFF     39
# 9165-PO AS DETECTIVE         28
# 9196-SUBPOENA OFFICER         8
# Name: Rank, dtype: int64

# %%
prof6[prof6['Appointed.Date'].isnull()]
# Out:
#          UID  Current.Unit  Star8  Birth.Year  Star6  Current.Age First.Name  \
# 3698    3699           NaN -999.0      1950.0 -999.0         66.0    ROSANNA
# 11047  11048           NaN -999.0      1954.0 -999.0         62.0    JAUNITA
# 13339  13340           NaN -999.0      1985.0 -999.0         31.0    JEFFERY
# 16670  16671           NaN -999.0      1957.0 -999.0         58.0    REBECCA
# 25113  25114         112.0 -999.0      -999.0 -999.0       -999.0      KELLY
# 27858  27859           NaN -999.0      1960.0 -999.0         55.0   SUEELLEN
#
#       Appointed.Date accused_ID  Star9       ...         trr_statuses_ID  \
# 3698             NaN        NaN -999.0       ...                     NaN
# 11047            NaN        NaN -999.0       ...                     NaN
# 13339            NaN        NaN -999.0       ...                     NaN
# 16670            NaN        NaN -999.0       ...                     NaN
# 25113            NaN        NaN -999.0       ...                     NaN
# 27858            NaN        NaN -999.0       ...                     NaN
#
#        Gender  unit_history_ID  Current.Star  Star1  Star5  Star10  Star2  \
# 3698   FEMALE           3649.0           NaN -999.0 -999.0  -999.0 -999.0
# 11047  FEMALE          10897.0           NaN -999.0 -999.0  -999.0 -999.0
# 13339    MALE          13162.0           NaN -999.0 -999.0  -999.0 -999.0
# 16670  FEMALE          16453.0           NaN -999.0 -999.0  -999.0 -999.0
# 25113  FEMALE          24779.0           NaN -999.0 -999.0  -999.0 -999.0
# 27858  FEMALE          27499.0           NaN -999.0 -999.0  -999.0 -999.0
#
#       Suffix.Name investigators_ID
# 3698          NaN              NaN
# 11047         NaN              NaN
# 13339         NaN              NaN
# 16670         NaN              NaN
# 25113         NaN              NaN
# 27858         NaN              NaN
#
# [6 rows x 30 columns]

# %%
awd[awd['Appointed.Date'].isnull()]
# Out:
#       awards_ID First.Name Last.Name Appointed.Date   Gender  Birth.Year  \
# 3098      23489     SYSTEM     CHRIS            NaN  UNKNOWN        1950
#
#       Current.Star
# 3098          -999

# %%
awdf[awdf['awards_ID'].isin(um2['awards_ID'])]['Rank'].value_counts()
# Out:
# 9161-POLICE OFFICER         174
# 9106-POLICE CADET            80
# 9164-PO/FIELD TRNING OFF     39
# 9165-PO AS DETECTIVE         28
# 9196-SUBPOENA OFFICER         8
# Name: Rank, dtype: int64

# %%
awd.shape
# Out:
# (21479, 7)
