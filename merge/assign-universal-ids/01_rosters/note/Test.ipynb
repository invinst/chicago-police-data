# %%
import pandas as pd
from assign_unique_ids_functions import *
from merge_functions import *
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
am = pd.read_csv('../input/all-members_demographics.csv.gz')
asw = pd.read_csv('../input/all-sworn_demographics.csv.gz')

# %%
atr_dict = append_to_reference(sub_df=asw, ref_df=pd.DataFrame(), profile_df=pd.DataFrame(),
                               print_merging=True, return_unmatched=True,
                              no_match_cols=['Last.Name'])

# %%
ref = atr_dict['ref']
prof = aggregate_data(ref, 'UID', mode_cols=listdiff(ref.columns,['UID']))

# %%
atr_dict2 = append_to_reference(sub_df=am, ref_df=ref, profile_df=prof,  print_merging=True, return_unmatched=True,
                              no_match_cols=['Last.Name'])
# Out:
# 31910 Matches on
# ['Suffix.Name', 'Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 3 Matches on
# ['Suffix.Name', 'Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name'] columns
# 1 Matches on
# ['Suffix.Name', 'Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 1 Matches on
# ['Suffix.Name', 'Race', 'Gender', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 1 Matches on
# ['Suffix.Name', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 8 Matches on
# ['Suffix.Name', 'Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'First.Name'] columns
# 31924 Total Merged. 99.74% of DF1 and 100.0% of DF2 Merged.
# 82 Unmerged in DF1. 0.26% Unmerged.
# 1 Unmerged in DF2. 0.0% Unmerged.

# %%
atr_dict2['UM2']
# Out:
#       all-members_ID  F4FN First.Name Middle.Initial2   Race Suffix.Name  \
# 1942           21523  NACA     NACALA             NaN  BLACK         NaN
#
#      Last.Name F4LN Appointed.Date  Birth.Year  Gender Middle.Initial
# 1942       BEY  BEY     1989-12-26      1964.0  FEMALE              M

# %%
atr_dict2['UM1']
# Out:
#          UID  F4FN   First.Name Middle.Initial2      Race Suffix.Name  \
# 100      101  JAIR       JAIRUS             NaN     BLACK         NaN
# 238      239  WILL       WILLIE             NaN     BLACK         NaN
# 483      484  ENRI      ENRIQUE             NaN  HISPANIC         NaN
# 893      894  HERI    HERIBERTO             NaN  HISPANIC         NaN
# 996      997  ABAL        ABALO             NaN     BLACK         NaN
# 1728    1729  ANGE       ANGELA             NaN  HISPANIC         NaN
# 2605    2606  VALE       VALENA             NaN   UNKNOWN         NaN
# 2800    2801  BRIA        BRIAN             NaN     BLACK         NaN
# 2890    2891  BRAN      BRANDON             NaN     BLACK         NaN
# 4940    4941  LUKE         LUKE             NaN     WHITE         NaN
# 5855    5856  ZACH      ZACHARY             NaN  HISPANIC         NaN
# 6485    6486  MARI        MARIA             NaN  HISPANIC         NaN
# ...
