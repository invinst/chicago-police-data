# %%
import pandas as pd
from assign_unique_ids_functions import *
from merge_functions import *
pd.options.display.max_columns = 1000

# %%
prof = pd.read_csv('../input/officer-profiles.csv.gz')
ref = pd.read_csv('../input/officer-reference.csv.gz')
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
awrd = pd.read_csv('../input/awards_demographics.csv.gz')

# %%
atr_dict = append_to_reference(sub_df=awrd, ref_df=ref, profile_df=prof, print_merging=True, return_unmatched=True,
                              no_match_cols=['Last.Name', 'Current.Star'], expand_stars=True)
# Out:
# 14860 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star9'] columns
# 10 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star6'] columns
# 38 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star5'] columns
# 141 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star4'] columns
# 479 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star3'] columns
# 1436 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star2'] columns
# 7795 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star1'] columns
# 130 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Current.Star'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN', 'Star9'] columns
# 2 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN', 'Star1'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name', 'Star9'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name', 'Star3'] columns
# 5 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name', 'Star1'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star2'] columns
# 3 Matches on
# ['Gender', 'Middle.Initial2', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star9'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star1'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN', 'Star9'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star9'] columns
# 1 Matches on
# ['Gender', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star9'] columns
# 1 Matches on
# ['Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name', 'Star1'] columns
# 3 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Star9'] columns
# 3 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Star2'] columns
# 26 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Star1'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Birth.Year', 'Appointed.Date', 'First.Name', 'Star9'] columns
# 1010 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'First.Name'] columns
# 1 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name', 'F4FN'] columns
# 2 Matches on
# ['Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'F4LN', 'First.Name'] columns
# 25954 Total Merged. 81.03% of DF1 and 99.33% of DF2 Merged.
# 6076 Unmerged in DF1. 18.97% Unmerged.
# 175 Unmerged in DF2. 0.67% Unmerged.

# %%
um1 = atr_dict['UM1']
um2 = atr_dict['UM2']

# %%
um2[um2['Appointed.Date']<='2016-08-29'].sort_values('Last.Name')
# Out:
#        awards_ID  F4FN  Gender    Star6    Star5    Star8  F4LN   Star10  \
# 23802       3410  CARL    MALE      NaN      NaN      NaN  APAR      NaN
# 1529        3144  BRIT  FEMALE      NaN      NaN      NaN  BLAC      NaN
# 23904        621  ALIC  FEMALE      NaN      NaN      NaN  BLAK      NaN
# 1836       15434  JONA    MALE      NaN      NaN      NaN  BOYD      NaN
# 3186       31229  UNDR  FEMALE      NaN      NaN      NaN  CHAN      NaN
# 3805        6065  DAVI    MALE      NaN      NaN      NaN  CONT      NaN
# 4883          91  ADAM    MALE      NaN      NaN      NaN  DEMB      NaN
# 24236      17074  KATH  FEMALE      NaN      NaN      NaN  DICK      NaN
# 24251       1177  ANGE  FEMALE      NaN      NaN      NaN  DOBY      NaN
# 5933       14434  JOHN    MALE      NaN      NaN      NaN  EVAN      NaN
# 24415      25550  RICH    MALE      NaN      NaN      NaN  FRAN      NaN
# 24448      28438  SERG    MALE      NaN      NaN      NaN  GALL      NaN
# 6866       19834  MARI  FEMALE      NaN      NaN      NaN  GALV      NaN
# 24456      26282  ROBE    MALE      NaN      NaN      NaN  GARC      NaN
# 7229       14501  JOHN    MALE      NaN      NaN      NaN  GIER      NaN
# 7242       10733  GLEN    MALE      NaN      NaN      NaN  GILB      NaN
# 24508       2954  BRIA    MALE      NaN      NaN      NaN  GORD      NaN
# 7920        7809  DWAY    MALE  14344.0  14344.0  14344.0  GROS  14344.0
# 8276        5011  CORI  FEMALE      NaN      NaN      NaN  HANS      NaN
# 24616      22746  NAKI  FEMALE      NaN      NaN      NaN  HARV      NaN
# 8537       22336  MICH  FEMALE      NaN      NaN      NaN  HAYE      NaN
# 24660      24891  RAND    MALE      NaN      NaN      NaN  HILL      NaN
# 9019        8563  ELIZ  FEMALE      NaN      NaN      NaN  HOFF      NaN
# 10053      23866  PATR    MALE      NaN      NaN      NaN  JONE      NaN
# 24861      29653  TANO  FEMALE      NaN      NaN      NaN  KITT      NaN
# 11398      24895  RAND    MALE      NaN      NaN      NaN  LANE      NaN
# 11524       6244  DAVI    MALE      NaN      NaN      NaN  LAVI      NaN
# 11547       4667  CHRI    MALE      NaN      NaN      NaN  LAWS      NaN
# 11551       1561  ANTH    MALE      NaN      NaN      NaN  LAYM      NaN
# 11739      31318  VASY    MALE  18342.0  18342.0  18342.0  LEVC  18342.0
# ...          ...   ...     ...      ...      ...      ...   ...      ...
# 13750      22690  MUND    MALE   9754.0   9754.0   9754.0  MEND   9754.0
# 14073      12000  JACQ  FEMALE  20259.0  20259.0  20259.0  MIZE  20259.0
# 14096      23937  PATR    MALE      NaN      NaN      NaN  MOHA      NaN
# 25221        298  ALBA  FEMALE      NaN      NaN      NaN  MORA      NaN
# 14295      28386  SEAN    MALE      NaN      NaN      NaN  MORA      NaN
# 14288      12712  JAME    MALE      NaN      NaN      NaN  MORA      NaN
# 14333      12714  JAME    MALE      NaN      NaN      NaN  MORG      NaN
# 25270      30878  TIMO    MALE      NaN      NaN      NaN  NALE      NaN
# 25432      28097  SANA  FEMALE      NaN      NaN      NaN  PICK      NaN
# 25439      17835  KIMM  FEMALE      NaN      NaN      NaN  PIKO      NaN
# 17088      17703  KEVI    MALE      NaN      NaN      NaN  RAKE      NaN
# 17739      28396  SEAN    MALE      NaN      NaN      NaN  ROBE      NaN
# 17893      12002  JACQ  FEMALE      NaN      NaN      NaN  RODR      NaN
# 18317       4680  CHRI    MALE      NaN      NaN      NaN  RUSI      NaN
# 25686       6378  DAVI    MALE      NaN      NaN      NaN  SEBO      NaN
# 25707       4444  CHRI    MALE      NaN      NaN      NaN  SHIU      NaN
# 19701      28426  SENE    MALE      NaN      NaN      NaN  SMIT      NaN
# 25816      12964  JAME    MALE      NaN      NaN      NaN  STEW      NaN
# 25874      17736  KEVI    MALE      NaN      NaN      NaN  TAYL      NaN
# 21634      19449  LYNN  FEMALE  14802.0  14802.0  14802.0  VEGA  14802.0
# 21837      13299  JASO    MALE      NaN      NaN      NaN  VONR      NaN
# 22010      30668  THOM    MALE      NaN      NaN      NaN  WALS      NaN
# 26015      21278  MERC  FEMALE      NaN      NaN      NaN  WATS      NaN
# 22263      21108  MAUR  FEMALE      NaN      NaN      NaN  WEBE      NaN
# 26033       7827  DWIG    MALE      NaN      NaN      NaN  WHIT      NaN
# 26035      24714  QUIN  FEMALE      NaN      NaN      NaN  WHIT      NaN
# 26067      22300  MICH    MALE  17643.0  17643.0  17643.0  WILS  17643.0
# 22821      29426  STEV    MALE      NaN      NaN      NaN  WITN      NaN
# 26094      23062  NICH    MALE  13289.0  13289.0  13289.0  WRIG  13289.0
# 26121       8386  EDYT  FEMALE   8527.0   8527.0   8527.0   ZUK   8527.0
#
#       Appointed.Date    Star3    Star4  Current.Star Middle.Initial2  \
# 23802     2006-07-16      NaN      NaN           NaN             NaN
# 1529      2010-04-16      NaN      NaN           NaN             NaN
# 23904     2006-07-16      NaN      NaN           NaN             NaN
# 1836      2010-04-16      NaN      NaN           NaN             NaN
# 3186      2010-09-01      NaN      NaN           NaN             NaN
# 3805      2004-09-27      NaN      NaN           NaN             NaN
# 4883      2007-11-01      NaN      NaN           NaN             NaN
# 24236     2007-11-01      NaN      NaN           NaN             NaN
# 24251     2006-07-16      NaN      NaN           NaN             NaN
# 5933      2010-09-01      NaN      NaN           NaN             NaN
# 24415     2007-11-01      NaN      NaN           NaN             NaN
# 24448     2006-07-16      NaN      NaN           NaN             NaN
# 6866      2010-04-16      NaN      NaN           NaN             NaN
# 24456     2006-04-28      NaN      NaN           NaN             NaN
# 7229      2003-01-27      NaN      NaN           NaN             NaN
# 7242      1949-02-28      NaN      NaN           NaN             NaN
# 24508     2006-04-28      NaN      NaN           NaN             NaN
# 7920      2012-04-02  14344.0  14344.0       14344.0             NaN
# 8276      2012-07-02      NaN      NaN           NaN             NaN
# 24616     2006-07-16      NaN      NaN           NaN             NaN
# 8537      1999-11-29      NaN      NaN           NaN             NaN
# 24660     2006-04-28      NaN      NaN           NaN             NaN
# 9019      2010-04-16      NaN      NaN           NaN             NaN
# 10053     2010-04-16      NaN      NaN           NaN             NaN
# 24861     1990-08-01      NaN      NaN           NaN             NaN
# 11398     2010-04-22      NaN      NaN           NaN             NaN
# 11524     2000-07-05      NaN      NaN           NaN             NaN
# 11547     1985-11-18      NaN      NaN           NaN             NaN
# 11551     2001-10-11      NaN      NaN           NaN             NaN
# 11739     2016-08-19  18342.0  18342.0       18342.0             NaN
# ...              ...      ...      ...           ...             ...
# 13750     2001-02-05   9754.0   9754.0        9754.0             NaN
# 14073     2005-09-26  20259.0  20259.0       20259.0             NaN
# 14096     2010-04-16      NaN      NaN           NaN             NaN
# 25221     2007-11-01      NaN      NaN           NaN             NaN
# 14295     2000-12-10      NaN      NaN           NaN             NaN
# 14288     2005-09-16      NaN      NaN           NaN             NaN
# 14333     1959-03-16      NaN      NaN           NaN             NaN
# 25270     2007-11-01      NaN      NaN           NaN             NaN
# 25432     2006-04-28      NaN      NaN           NaN             NaN
# 25439     2007-11-01      NaN      NaN           NaN             NaN
# 17088     1998-10-01      NaN      NaN           NaN             NaN
# 17739     2004-01-26      NaN      NaN           NaN             NaN
# 17893     2010-04-16      NaN      NaN           NaN             NaN
# 18317     2012-12-14      NaN      NaN           NaN             NaN
# 25686     1990-07-10      NaN      NaN           NaN             NaN
# 25707     2007-11-01      NaN      NaN           NaN             NaN
# 19701     2012-07-02      NaN      NaN           NaN             NaN
# 25816     2006-04-28      NaN      NaN           NaN             NaN
# 25874     2007-11-01      NaN      NaN           NaN             NaN
# 21634     2007-06-18  14802.0  14802.0       14802.0             NaN
# 21837     2004-09-27      NaN      NaN           NaN             NaN
# 22010     1959-12-16      NaN      NaN           NaN             NaN
# 26015     2005-09-16      NaN      NaN           NaN             NaN
# 22263     2010-04-16      NaN      NaN           NaN             NaN
# 26033     2007-11-01      NaN      NaN           NaN             NaN
# 26035     2006-04-28      NaN      NaN           NaN             NaN
# 26067     2008-04-07  17643.0  17643.0       17643.0             NaN
# 22821     2002-01-07      NaN      NaN           NaN             NaN
# 26094     2013-11-16  13289.0  13289.0       13289.0             NaN
# 26121     2016-08-29   8527.0   8527.0        8527.0             NaN
#
#       Middle.Initial    Star2    Star1    Star7      Last.Name    Star9  \
# 23802              P      NaN      NaN      NaN       APARICIO      NaN
# 1529               J      NaN      NaN      NaN      BLACKWELL      NaN
# 23904              Y      NaN      NaN      NaN          BLAKE      NaN
# 1836             NaN      NaN      NaN      NaN           BOYD      NaN
# 3186               N      NaN      NaN      NaN       CHANDLER      NaN
# 3805             NaN      NaN      NaN      NaN      CONTRERAS      NaN
# 4883               M      NaN      NaN      NaN      DEMBOWSKI      NaN
# 24236            NaN      NaN      NaN      NaN         DICKEY      NaN
# 24251            NaN      NaN      NaN      NaN        DOBYNES      NaN
# 5933               P      NaN      NaN      NaN          EVANS      NaN
# 24415              B      NaN      NaN      NaN        FRANCIS      NaN
# 24448            NaN      NaN      NaN      NaN       GALLEGOS      NaN
# 6866               G      NaN      NaN      NaN         GALVEZ      NaN
# 24456            NaN      NaN      NaN      NaN         GARCIA      NaN
# 7229             NaN      NaN      NaN      NaN         GIERES      NaN
# 7242               H      NaN      NaN      NaN       GILBRETH      NaN
# 24508              A      NaN      NaN      NaN         GORDON      NaN
# 7920             NaN  14344.0  14344.0  14344.0          GROSS  14344.0
# 8276             NaN      NaN      NaN      NaN         HANSON      NaN
# 24616              D      NaN      NaN      NaN         HARVEY      NaN
# 8537             NaN      NaN      NaN      NaN          HAYES      NaN
# 24660              J      NaN      NaN      NaN         HILLER      NaN
# 9019             NaN      NaN      NaN      NaN        HOFFMAN      NaN
# 10053              R      NaN      NaN      NaN          JONES      NaN
# 24861              A      NaN      NaN      NaN       KITTRELL      NaN
# 11398              M      NaN      NaN      NaN           LANE      NaN
# 11524              P      NaN      NaN      NaN          LAVIN      NaN
# 11547              M      NaN      NaN      NaN         LAWSON      NaN
# 11551            NaN      NaN      NaN      NaN         LAYMAN      NaN
# 11739            NaN  18342.0  18342.0  18342.0      LEVCHENKO  18342.0
# ...              ...      ...      ...      ...            ...      ...
# 13750            NaN   9754.0   9754.0   9754.0        MENDOZA   9754.0
# 14073              M  20259.0  20259.0  20259.0         MIZERA  20259.0
# 14096              J      NaN      NaN      NaN          MOHAN      NaN
# 25221              M      NaN      NaN      NaN        MORALES      NaN
# 14295              M      NaN      NaN      NaN          MORAN      NaN
# 14288              P      NaN      NaN      NaN          MORAN      NaN
# 14333              J      NaN      NaN      NaN         MORGAN      NaN
# 25270              M      NaN      NaN      NaN        NALEWAY      NaN
# 25432            NaN      NaN      NaN      NaN        PICKETT      NaN
# 25439            NaN      NaN      NaN      NaN       PIKOWSKI      NaN
# 17088              J      NaN      NaN      NaN           RAKE      NaN
# 17739            NaN      NaN      NaN      NaN        ROBERTS      NaN
# 17893              D      NaN      NaN      NaN      RODRIGUEZ      NaN
# 18317            NaN      NaN      NaN      NaN          RUSIN      NaN
# 25686              J      NaN      NaN      NaN          SEBOK      NaN
# 25707              K      NaN      NaN      NaN           SHIU      NaN
# 19701              G      NaN      NaN      NaN          SMITH      NaN
# 25816              J      NaN      NaN      NaN        STEWART      NaN
# 25874            NaN      NaN      NaN      NaN         TAYLOR      NaN
# 21634              M  14802.0  14802.0  14802.0           VEGA  14802.0
# 21837              K      NaN      NaN      NaN  VONREICHBAUER      NaN
# 22010              M      NaN      NaN      NaN          WALSH      NaN
# 26015              M      NaN      NaN      NaN         WATSON      NaN
# 22263              T      NaN      NaN      NaN          WEBER      NaN
# 26033              A      NaN      NaN      NaN          WHITE      NaN
# 26035              R      NaN      NaN      NaN          WHITE      NaN
# 26067              A  17643.0  17643.0  17643.0         WILSON  17643.0
# 22821              M      NaN      NaN      NaN         WITNIK      NaN
# 26094              D  13289.0  13289.0  13289.0         WRIGHT  13289.0
# 26121              W   8527.0   8527.0   8527.0            ZUK   8527.0
#
#         First.Name  Birth.Year
# 23802       CARLOS      1986.0
# 1529      BRITTNEY      1985.0
# 23904       ALICIA      1985.0
# 1836      JONATHAN      1978.0
# 3186        UNDREA      1976.0
# 3805         DAVID      1973.0
# 4883          ADAM      1986.0
# 24236      KATHRYN      1986.0
# 24251     ANGELICA      1987.0
# 5933          JOHN      1985.0
# 24415      RICHARD      1987.0
# 24448       SERGIO      1986.0
# 6866         MARIA      1985.0
# 24456       ROBERT      1986.0
# 7229          JOHN      1966.0
# 7242          GLEN      1921.0
# 24508        BRIAN      1986.0
# 7920        DWAYNE      1987.0
# 8276        CORINA      1974.0
# 24616        NAKIA      1984.0
# 8537       MICHELE      1968.0
# 24660      RANDALL      1987.0
# 9019     ELIZABETH      1972.0
# 10053      PATRICK      1983.0
# 24861        TANOA      1962.0
# 11398      RANDALL      1976.0
# 11524        DAVID      1967.0
# 11547  CHRISTOPHER      1957.0
# 11551      ANTHONY      1978.0
# 11739        VASYL      1985.0
# ...            ...         ...
# 13750        MUNDO      1973.0
# 14073   JACQUELINE      1981.0
# 14096      PATRICK      1985.0
# 25221         ALBA      1988.0
# 14295         SEAN      1976.0
# 14288        JAMES      1985.0
# 14333        JAMES      1934.0
# 25270      TIMOTHY      1986.0
# 25432      SANAVIA      1987.0
# 25439    KIMMERRIE      1988.0
# 17088        KEVIN      1942.0
# 17739         SEAN      1966.0
# 17893   JACQUELINE      1985.0
# 18317  CHRISTOPHER      1986.0
# 25686        DAVID      1966.0
# 25707    CHRISTIAN      1988.0
# 19701       SENECA      1980.0
# 25816        JAMES      1987.0
# 25874        KEVIN      1986.0
# 21634     LYNNETTE      1990.0
# 21837        JASON      1972.0
# 22010       THOMAS      1934.0
# 26015     MERCEDES      1987.0
# 22263      MAUREEN      1981.0
# 26033       DWIGHT      1987.0
# 26035    QUINRETTA      1986.0
# 26067      MICHAEL      1977.0
# 22821       STEVEN      1978.0
# 26094     NICHOLAS      1995.0
# 26121        EDYTA      1988.0
#
# [67 rows x 21 columns]

# %%
prof[(prof['First.Name'].str.contains('BRIT')) & (prof['Last.Name'].str.contains(''))].sort_values('Appointed.Date')
# Out:
#          UID  Star3  trr-officers_ID  trr-statuses_ID  Current.Unit  \
# 7248    7249    NaN              NaN              NaN           6.0
# 17638  17639    NaN              NaN              NaN          44.0
# 30476  30477    NaN              NaN              NaN          44.0
#
#        Birth.Year      Race  investigators_ID Appointed.Date  \
# 7248       1988.0     BLACK               NaN     2015-02-02
# 17638      1989.0  HISPANIC               NaN     2016-04-25
# 30476      1991.0     BLACK               NaN     2016-06-27
#
#        all-sworn-units_ID  ase-units_ID  Star6 Last.Name  all-sworn_ID  \
# 7248               2764.0        7164.0    NaN    DOTSON        2764.0
# 17638              2765.0           NaN    NaN  MARTINEZ        2765.0
# 30476              2763.0           NaN    NaN     WELLS        2763.0
#
#        all-members_ID  Star9 Middle.Initial2  Star5  accused_ID    Star1  \
# 7248           2753.0    NaN             NaN    NaN         NaN  14200.0
# 17638          2754.0    NaN             NaN    NaN         NaN      NaN
# 30476          2752.0    NaN             NaN    NaN         NaN      NaN
#
#        Star2  Star4  Star10 Current.Rank Suffix.Name  Current.Age First.Name  \
# 7248     NaN    NaN     NaN          NaN         NaN         27.0   BRITTNAY
# 17638    NaN    NaN     NaN          NaN         NaN          NaN    BRITTNI
# 30476    NaN    NaN     NaN          NaN         NaN          NaN   BRITTANY
#
#        Gender  Current.Star  Star8 Middle.Initial  Star7
# 7248   FEMALE           NaN    NaN              L    NaN
# 17638  FEMALE           NaN    NaN              E    NaN
# 30476  FEMALE           NaN    NaN              T    NaN
