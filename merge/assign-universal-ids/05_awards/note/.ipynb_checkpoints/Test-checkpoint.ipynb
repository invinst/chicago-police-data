# %%
import pandas as pd
from assign_unique_ids_functions import *
from merge_functions import *
pd.options.display.max_columns = 1000

# %%
prof = pd.read_csv('../input/officer-profiles.csv.gz')
ref = pd.read_csv('../input/officer-reference.csv.gz')
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3,13,15,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
awrd = pd.read_csv('../input/awards_demographics.csv.gz')

# %%
atr_dict = append_to_reference(sub_df=awrd, ref_df=ref, profile_df=prof, print_merging=True, return_unmatched=True,
                              no_match_cols=['Last.Name_NS', 'Current.Star', 'First.Name_NS'],
                               custom_matches=[["Appointed.Date", "Birth.Year", "Middle.Initial", "Star1", "Gender"]], expand_stars=True)
# Out:
# 14872 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star9'] columns
# 14 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star6'] columns
# 55 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star5'] columns
# 193 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star4'] columns
# 606 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star3'] columns
# 1617 Matches on
# ['Race', 'Gender', 'Middle.Initial2', 'Middle.Initial', 'Birth.Year', 'Appointed.Date', 'Last.Name_NS', 'First.Name_NS', 'Star2'] columns
# 8188 Matches on
# ...

# %%
um1 = atr_dict['UM1']
um2 = atr_dict['UM2']
appd = intersect(um1['Appointed.Date'], um2['Appointed.Date'])

# %%
ref[ref['UID']==2610]
prof[prof['UID']==2610]
# Out:
#        UID First.Name_NS Last.Name_NS Middle.Initial Suffix.Name  \
# 2609  2610        NACALA          BEY              M         NaN
#
#      Middle.Initial2   Race  Gender  Birth.Year Appointed.Date  \
# 2609             NaN  BLACK  FEMALE      1964.0     1989-12-26
#
#      Resignation.Date Current.Rank  Current.Age  Current.Unit  Current.Star  \
# 2609              NaN           PO         52.0           2.0       17810.0
#
#         Star1    Star2  Star3  Star4  Star5  Star6  Star7  Star8  Star9  \
# 2609  17810.0  10029.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       Star10  trr-officers_ID  cpd-employees_ID  trr-statuses_ID  accused_ID  \
# 2609     NaN           8577.0           29956.0           9281.0     15287.0
#
#       all-sworn-units_ID  ase-units_ID  investigators_ID  profile_count
# 2609             30161.0        1918.0               NaN              6

# %%
um2[um2['Appointed.Date'].isin(appd)].sort_values('Appointed.Date')
# Out:
#        awards_ID  Current.Star   Star10 Resignation.Date  Birth.Year  F4LN  \
# 7242       10734           NaN      NaN       1982-08-01      1921.0  GILB
# 14333      12718           NaN      NaN       1987-06-16      1934.0  MORG
# 22010      30673           NaN      NaN       1985-04-16      1934.0  WALS
# 1895       31252       17810.0  17810.0              NaN      1964.0  BRAD
# 1382       22421           NaN      NaN       2013-05-10      1968.0  BERR
# 13750      22693        9754.0   9754.0              NaN      1973.0  MEND
# 17739      28399           NaN      NaN              NaN      1966.0  ROBE
# 3805        6066           NaN      NaN              NaN      1973.0  CONT
# 21837      13303           NaN      NaN              NaN      1972.0  VONR
# 14073      12004       20259.0  20259.0              NaN      1981.0  MIZE
# 3186       31234           NaN      NaN              NaN      1976.0  CHAN
# ...

# %%
um1[um1['Appointed.Date'].isin(appd) & um1['Last.Name_NS'].isin(um2[um2['Appointed.Date'].isin(appd)]['Last.Name_NS'])
   ].sort_values('Appointed.Date')
# Out:
#          UID  Current.Star  Star10 Resignation.Date  Birth.Year  F4LN  Star3  \
# 24196  24197           NaN     NaN              NaN      1962.0  ROBE    NaN
# 19300  19301        5037.0     NaN              NaN      1981.0  MIZE    NaN
#
#        Star4  Star9 Middle.Initial2 First.Name_NS      Race  Star8  Gender  \
# 24196    NaN    NaN             NaN          KIRK     BLACK    NaN    MALE
# 19300    NaN    NaN             NaN        JACKIE  HISPANIC    NaN  FEMALE
#
#       Last.Name_NS Middle.Initial   Star1 Appointed.Date  F4FN  Star5   Star2  \
# 24196      ROBERTS              B     NaN     1989-12-26  KIRK    NaN     NaN
# 19300       MIZERA              M  5037.0     2005-09-26  JACK    NaN  5037.0
#
#        Star7  Star6
# 24196    NaN    NaN
# 19300    NaN    NaN

# %%
prof[(prof['First.Name_NS'].str.contains('BRIT')) & (prof['Last.Name_NS'].str.contains(''))].sort_values('Appointed.Date')
# Out:
#          UID First.Name_NS Last.Name_NS Middle.Initial Suffix.Name  \
# 7226    7227      BRITTNAY       DOTSON              L         NaN
# 17562  17563       BRITTNI     MARTINEZ              E         NaN
# 30342  30343      BRITTANY        WELLS              T         NaN
# 23486  23487      BRITTANY       RAPIER            NaN         NaN
#
#       Middle.Initial2      Race  Gender  Birth.Year Appointed.Date  \
# 7226              NaN     BLACK  FEMALE      1988.0     2015-02-02
# 17562             NaN  HISPANIC  FEMALE      1989.0     2016-04-25
# 30342             NaN     BLACK  FEMALE      1991.0     2016-06-27
# 23486             NaN     WHITE  FEMALE      1986.0     2017-01-17
#
#       Resignation.Date Current.Rank  Current.Age  Current.Unit  Current.Star  \
# 7226               NaN          NaN         27.0           6.0           NaN
# 17562              NaN          NaN         27.0          44.0           NaN
# ...
