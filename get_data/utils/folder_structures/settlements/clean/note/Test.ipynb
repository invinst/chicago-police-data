# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../input/settlements_1952-2016_2017-01.csv.gz")

# %%
df["current_status"] = df["service_length"].map(check_active)

# %%
df
# Out:
#       Unnamed: 0      case_id  officer_id first_name    last_name  \
# 0              0   14-CV-4800     24165.0     STEVEN      SAUTKUS
# 1              1   14-CV-7969     24165.0     STEVEN      SAUTKUS
# 2              2    15-CV-111     24165.0     STEVEN      SAUTKUS
# 3              3   13-CV-1477     24165.0     STEVEN      SAUTKUS
# 4              4   10-CV-2916     24165.0     STEVEN      SAUTKUS
# 5              5   14-CV-4800     23142.0       SEAN     CAMPBELL
# 6              6   14-CV-7969     23142.0       SEAN     CAMPBELL
# 7              7    15-CV-111     23142.0       SEAN     CAMPBELL
# 8              8   12-CV-8965     23142.0       SEAN     CAMPBELL
# 9              9   13-CV-1477     23142.0       SEAN     CAMPBELL
# 10            10   14-CV-4800     27027.0      EMILY     CAMPBELL
# 11            11   14-CV-4800     23397.0    MICHAEL     CAMPBELL
# 12            12   14-CV-4375     23397.0    MICHAEL     CAMPBELL
# ...
