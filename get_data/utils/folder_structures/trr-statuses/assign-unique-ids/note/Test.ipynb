# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv('../input/trr-statuses.csv.gz')

# %%
print(df.shape)
df.head()
# Out:
# (201401, 14)
#        Rank Status.Time Status.Date      Race Appointed.Date   Star Gender  \
# 0   OFFICER    18:20:00  2004-01-17  HISPANIC     1994-01-18   3646   MALE
# 1  SERGEANT    18:25:00  2004-01-17  HISPANIC     1991-01-30   1652   MALE
# 2   CAPTAIN    19:28:00  2004-01-17     WHITE     1973-10-22     27   MALE
# 3   OFFICER    18:23:00  2004-01-17  HISPANIC     1985-11-18  17714   MALE
# 4  SERGEANT    18:26:00  2004-01-17  HISPANIC     1991-01-30   1652   MALE
#
#    Current.Age  TRR.ID     Status  Last.Name Suffix.Name First.Name  \
# 0           36       4  SUBMITTED  VELAZQUEZ         NaN     ANGELO
# 1           37       4   REVIEWED       RIOS         NaN       JUAN
# 2           52       4   APPROVED      ELMER         NaN    RICHARD
# 3           47       5  SUBMITTED      REYES         NaN      ANDRE
# 4           37       5   REVIEWED       RIOS         NaN       JUAN
#
#    Middle.Initial
# 0             NaN
# 1             NaN
# 2             NaN
# ...

# %%
df.sort_values(['First.Name', 'Last.Name']).head(10)
# Out:
#            Rank Status.Time Status.Date      Race Appointed.Date  Star Gender  \
# 106388  OFFICER    19:50:00  2010-08-13  HISPANIC     2009-12-16  7792   MALE
# 109936  OFFICER    19:58:00  2010-10-24  HISPANIC     2009-12-16  7792   MALE
# 117133  OFFICER    16:37:00  2011-04-20  HISPANIC     2009-12-16  7792   MALE
# 123044  OFFICER    19:57:00  2011-07-31  HISPANIC     2009-12-16  7792   MALE
# 126208  OFFICER    23:51:00  2011-09-30  HISPANIC     2009-12-16  7792   MALE
# 126229  OFFICER    16:20:00  2011-10-01  HISPANIC     2009-12-16  7792   MALE
# 128397  OFFICER    16:51:00  2011-11-17  HISPANIC     2009-12-16  7792   MALE
# 134425  OFFICER    01:07:00  2012-03-29  HISPANIC     2009-12-16  7792   MALE
# 134936  OFFICER    23:24:00  2012-04-10  HISPANIC     2009-12-16  7792   MALE
# 141561  OFFICER    18:20:00  2012-08-09  HISPANIC     2009-12-16  7792   MALE
#
#         Current.Age  TRR.ID     Status Last.Name Suffix.Name First.Name  \
# ...

# %%
id_cols = ["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name",
          "Appointed.Date", "Race", "Gender", "Current.Age", "Star", "Rank"]

# %%
dfu = df[id_cols].drop_duplicates()

# %%
dfu.shape
# Out:
# (47866, 10)

# %%
id_cols = ["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name",
          "Appointed.Date", "Race", "Gender", "Current.Age"]
keep_duplicates(dfu, id_cols)
# Out:
#        First.Name    Last.Name  Middle.Initial Suffix.Name Appointed.Date  \
# 140832      AARON   CUNNINGHAM             NaN         NaN     1998-06-29
# 156619      AARON   CUNNINGHAM             NaN         NaN     1998-06-29
# 14430       AARON    PORADZISZ             NaN         NaN     2004-04-26
# 26386       AARON    PORADZISZ             NaN         NaN     2004-04-26
# 44633     ALBERTA      RAYMOND             NaN         NaN     1978-12-11
# 45658     ALBERTA      RAYMOND             NaN         NaN     1978-12-11
# 50505      ALFRED       NAGODE             NaN         NaN     1988-12-05
# 56730      ALFRED       NAGODE             NaN         NaN     1988-12-05
# 10811       ALLEN         CAIN             NaN         NaN     1991-11-18
# 11231       ALLEN         CAIN             NaN         NaN     1991-11-18
# 136811      ALVIN        JONES             NaN         NaN     1996-03-18
# 152417      ALVIN        JONES             NaN         NaN     1996-03-18
# ...

# %%
dfu[dfu['First.Name']=='DAVID'][dfu['Last.Name']=='RODGERS']
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        First.Name Last.Name  Middle.Initial Suffix.Name Appointed.Date   Race  \
# 168216      DAVID   RODGERS             NaN         NaN     2005-12-05  BLACK
#
#        Gender  Current.Age  Star Rank
# 168216   MALE           43  -999  NaN
