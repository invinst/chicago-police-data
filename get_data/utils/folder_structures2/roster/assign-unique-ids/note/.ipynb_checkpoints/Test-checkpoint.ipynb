# %%
import pandas as pd
from assign_unique_ids_functions import *
from general_utils import *
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('../input/roster__2018-03.csv.gz')

# %%
df.query('~(is_sworn_officer == "Y" | is_sworn_officer == "N")')
# Out:
# Empty DataFrame
# Columns: [row_id, gender, race, current_age, is_sworn_officer, appointed_date, rank_no, unit_id, unit, unit_detail, resignation_date, current_star, first_name, first_name_NS, last_name, last_name_NS, middle_initial, middle_initial2, suffix_name]
# Index: []

# %%
df.columns
# Out:
# Index(['row_id', 'gender', 'race', 'current_age', 'is_sworn_officer',
#        'appointed_date', 'rank_no', 'unit_id', 'unit', 'unit_detail',
#        'resignation_date', 'current_star', 'first_name', 'first_name_NS',
#        'last_name', 'last_name_NS', 'middle_initial', 'middle_initial2',
#        'suffix_name'],
#       dtype='object')

# %%
keep_duplicates(df,['first_name_NS', 'last_name_NS', 'appointed_date'])
# Out:
#        row_id gender      race  current_age is_sworn_officer appointed_date  \
# 9265     9266   MALE     BLACK         26.0                Y     2017-11-16
# 9445     9446   MALE     BLACK         38.0                Y     2017-11-16
# 1554     1555   MALE     WHITE         34.0                Y     2009-12-16
# 1894     1895   MALE     WHITE         34.0                Y     2009-12-16
# 10463   10464   MALE     WHITE         33.0                Y            NaN
# 12728   13275   MALE       NaN         32.0                N            NaN
# 2662     2663   MALE     WHITE         51.0                Y     1999-09-13
# 3509     3510   MALE     WHITE         42.0                Y     1999-09-13
# 11119   11120   MALE     WHITE         65.0                N            NaN
# 11600   11601   MALE       NaN         62.0                N            NaN
# 2061     2062   MALE  HISPANIC         29.0                Y     2014-05-27
# 3075     3076   MALE  HISPANIC         34.0                Y     2014-05-27
# 1584     1585   MALE  HISPANIC         31.0                Y     2016-08-29
# 3990     3991   MALE  HISPANIC         28.0                Y     2016-08-29
#
#       rank_no  unit_id   unit  unit_detail resignation_date  current_star  \
# 9265     9161     37.0   44.0          NaN              NaN           NaN
# 9445     9161     37.0   44.0          NaN              NaN           NaN
# 1554     9161      9.0    4.0          NaN              NaN        8791.0
# 1894     9161    142.0    5.0        193.0              NaN       10927.0
# 10463    9161     37.0   44.0          NaN              NaN           NaN
# 12728     UNK    161.0  376.0          NaN              NaN           NaN
# 2662     9161     12.0    7.0          NaN              NaN       15151.0
# 3509     9171    329.0    8.0        211.0              NaN        1182.0
# 11119    0102    310.0  114.0          NaN              NaN           NaN
# 11600     UNK     89.0  125.0          NaN              NaN           NaN
# 2061     9161     10.0    5.0          NaN       2014-05-15       16756.0
# 3075     9161     12.0    7.0          NaN              NaN       16753.0
# 1584     9161      9.0    4.0          NaN              NaN        8590.0
# 3990     9161     14.0    9.0          NaN              NaN        8391.0
#
#       first_name first_name_NS last_name last_name_NS middle_initial  \
# 9265      DANIEL        DANIEL   JOHNSON      JOHNSON              R
# 9445      DANIEL        DANIEL   JOHNSON      JOHNSON              A
# 1554       JAMES         JAMES   BANSLEY      BANSLEY              H
# 1894       JAMES         JAMES   BANSLEY      BANSLEY              A
# 10463       JOHN          JOHN     ISHAQ        ISHAQ              A
# 12728       JOHN          JOHN     ISHAQ        ISHAQ            NaN
# 2662       KEVIN         KEVIN   CONNORS      CONNORS              M
# 3509       KEVIN         KEVIN   CONNORS      CONNORS              M
# 11119      KEVIN         KEVIN   SHANLEY      SHANLEY              O
# 11600      KEVIN         KEVIN   SHANLEY      SHANLEY              O
# 2061     RICARDO       RICARDO    TORRES       TORRES              J
# 3075     RICARDO       RICARDO    TORRES       TORRES            NaN
# 1584      ROBERT        ROBERT    RIVERA       RIVERA            NaN
# 3990      ROBERT        ROBERT    RIVERA       RIVERA              M
#
#       middle_initial2 suffix_name
# 9265              NaN         NaN
# 9445              NaN         NaN
# 1554              NaN         NaN
# 1894              NaN         NaN
# 10463             NaN         NaN
# 12728             NaN         NaN
# 2662              NaN         NaN
# 3509              NaN         NaN
# 11119             NaN         NaN
# 11600             NaN         NaN
# 2061              NaN         NaN
# 3075              NaN         NaN
# 1584              NaN          JR
# 3990              NaN         NaN
