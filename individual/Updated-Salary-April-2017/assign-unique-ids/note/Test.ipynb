# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv("../input/salary.csv.gz")
df.head()
# Out:
#   Pay.Grade           Title  Year    SPP.Date              Employee.Status  \
# 0       D|1  POLICE OFFICER  2002  1994-08-01               CAREER SERVICE
# 1       D|1  POLICE OFFICER  2002  2002-07-29  PROBATIONARY CAREER SERVICE
# 2       D|1  POLICE OFFICER  2002  1998-07-27               CAREER SERVICE
# 3       D|1  POLICE OFFICER  2002  1998-07-27               CAREER SERVICE
# 4       D|1  POLICE OFFICER  2002  1990-03-26               CAREER SERVICE
#
#    Gender  Age.at.Hire  Start.Date  Salary Org.Hire.Date   Last.Name  \
# 0    MALE         29.0  1994-08-01   57426    1994-08-01  TALIAFERRO
# 1    MALE         30.0  2002-07-29   36984    1994-07-01      CHEREK
# 2    MALE         24.0  1998-07-27   54672    1998-07-27      GAINER
# 3  FEMALE         28.0  1998-07-27   54672    1998-07-27      REWERS
# 4    MALE         32.0  1990-03-26   59412    1990-03-26      MCGRAW
#
#    First.Name Middle.Initial Middle.Initial2 Suffix.Name
# ...

# %%
df[df['Middle.Initial2'].notnull()]
# Out:
#        Pay.Grade           Title  Year    SPP.Date Employee.Status  Gender  \
# 345          D|1  POLICE OFFICER  2002  1991-11-18  CAREER SERVICE  FEMALE
# 13850        D|1  POLICE OFFICER  2003  1991-11-18  CAREER SERVICE  FEMALE
# 28197        D|1  POLICE OFFICER  2004  1991-11-18  CAREER SERVICE  FEMALE
# 42345        D|1  POLICE OFFICER  2005  1991-11-18  CAREER SERVICE  FEMALE
# 56439        D|1  POLICE OFFICER  2006  1991-11-18  CAREER SERVICE  FEMALE
# 70581        D|1  POLICE OFFICER  2007  1991-11-18  CAREER SERVICE  FEMALE
# 84680        D|1  POLICE OFFICER  2008  1991-11-18  CAREER SERVICE  FEMALE
# 98448        D|1  POLICE OFFICER  2009  1991-11-18  CAREER SERVICE  FEMALE
# 111721       D|1  POLICE OFFICER  2010  1991-11-18  CAREER SERVICE  FEMALE
# 124841       D|1  POLICE OFFICER  2011  1991-11-18  CAREER SERVICE  FEMALE
# 137455       D|1  POLICE OFFICER  2012  1991-11-18  CAREER SERVICE  FEMALE
# ...

# %%
tdf = df.loc[df["Year"]==2003]

# %%
kd = keep_duplicates(tdf, ["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name", "Age.at.Hire", "Org.Hire.Date", "Start.Date", "Salary"])
print(kd.shape)
kd
# Out:
# (912, 14)
#        Year  Salary Org.Hire.Date Pay.Grade  \
# 17457  2003   63456    1997-03-17       D|1
# 17458  2003   63456    1997-03-17      D|2A
# 18456  2003   70488    1995-06-05       D|1
# 18457  2003   70488    1995-06-05       E|3
# 16449  2003   65868    1987-12-07       D|1
# 16450  2003   65868    1987-12-07       D|2
# 13949  2003   63456    1997-08-04       D|1
# 13950  2003   63456    1997-08-04      D|2A
# 17815  2003   70488    1996-03-18       D|1
# 17816  2003   70488    1996-03-18       E|3
# 14224  2003   65646    1990-03-26       D|1
# 14225  2003   65646    1990-03-26      D|2A
# 20392  2003   70488    1995-12-04       D|1
# 20393  2003   70488    1995-12-04       E|3
# 22759  2003   58572    1990-06-01       D|1
# 22760  2003   58572    1990-06-01       D|2
# 17039  2003   58572    1996-12-02       D|1
# 17040  2003   58572    1996-12-02      D|2A
# 19403  2003   70488    1994-10-17       D|3
# 19404  2003   70488    1994-10-17       D|1
# ...

# %%
tdf = df.loc[df["Year"]==2003]
tdf[tdf['First.Name'] == 'ANTHONY'][tdf['Last.Name']=='GIBBONS']
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        Year  Age.at.Hire           Title    Org.Date Gender    SPP.Date  \
# 85778  2003         31.0  POLICE OFFICER  1991-01-30   MALE  1991-01-30
#
#         Salary  Start.Date Pay.Grade Employee.Status Last.Name Suffix.Name  \
# 85778  60600.0  1991-01-30       D|1  CAREER SERVICE   GIBBONS         NaN
#
#       First.Name Middle.Initial
# 85778    ANTHONY              V

# %%
kd = keep_duplicates(tdf, ["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name", "Age.at.Hire", "Salary"])
print(kd.shape)
kd
# Out:
# (912, 14)
#        Year  Age.at.Hire                                             Title  \
# 80213  2003         31.0                                    POLICE OFFICER
# 80214  2003         31.0            POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 81212  2003         24.0                                    POLICE OFFICER
# 81213  2003         24.0                                          SERGEANT
# 79205  2003         27.0                                    POLICE OFFICER
# 79206  2003         27.0                                      POLICE AGENT
# 76705  2003         26.0                                    POLICE OFFICER
# 76706  2003         26.0            POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 80571  2003         22.0                                    POLICE OFFICER
# 80572  2003         22.0                                          SERGEANT
# 76980  2003         23.0                                    POLICE OFFICER
# ...

# %%
tdf.loc[tdf["Start.Date"].isnull() & tdf["Org.Date"].isnull() & tdf["SPP.Date"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Age.at.Hire, Title, Org.Date, Gender, SPP.Date, Salary, Start.Date, Pay.Grade, Employee.Status, Last.Name, Suffix.Name, First.Name, Middle.Initial]
# Index: []

# %%
tdf.loc[tdf["Start.Date"].isnull() & tdf["Org.Date"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Age.at.Hire, Title, Org.Date, Gender, SPP.Date, Salary, Start.Date, Pay.Grade, Employee.Status, Last.Name, Suffix.Name, First.Name, Middle.Initial]
# Index: []

# %%
tdf.loc[tdf["Start.Date"].isnull() & tdf["SPP.Date"].isnull()]
# Out:
#        Year  Age.at.Hire                                         Title  \
# 62762  2002          NaN        POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 62771  2002          NaN                                      SERGEANT
# 62793  2002          NaN     POLICE OFFICER (ASSIGNED AS INVESTIGATOR)
# 62851  2002          NaN                         DEPUTY SUPERINTENDENT
# 62880  2002          NaN                                      SERGEANT
# 62924  2002          NaN                                POLICE OFFICER
# 62933  2002          NaN                                      SERGEANT
# 62959  2002          NaN                                POLICE OFFICER
# 62972  2002          NaN        POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 62973  2002          NaN        POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 62976  2002          NaN     POLICE OFFICER (ASSIGNED AS INVESTIGATOR)
# 62981  2002          NaN        POLICE OFFICER (ASSIGNED AS DETECTIVE)
# ...

# %%
tdf.loc[tdf["Org.Date"].isnull() & tdf["SPP.Date"].isnull()]
# Out:
#        Year  Age.at.Hire                                             Title  \
# 66838  2002         37.0                                          SERGEANT
# 71019  2002         27.0  POLICE OFFICER (ASSIGNED AS EVIDENCE TECHNICIAN)
# 75952  2002         32.0            POLICE OFFICER (ASSIGNED AS DETECTIVE)
#
#       Org.Date Gender SPP.Date   Salary  Start.Date Pay.Grade Employee.Status  \
# 66838      NaN   MALE      NaN  78450.0  1983-04-01       E|3  CAREER SERVICE
# 71019      NaN   MALE      NaN  71382.0  1971-07-26       D|2  CAREER SERVICE
# 75952      NaN   MALE      NaN  73476.0  1973-03-19      D|2A  CAREER SERVICE
#
#       Last.Name Suffix.Name First.Name Middle.Initial
# 66838     BLAKE         NaN     STEVEN            NaN
# 71019   FONDREN         NaN        ROY            NaN
# 75952    THOMAS         NaN  CLEVELAND            NaN

# %%
df.loc[df["Start.Date"].isnull() & df["Org.Date"].isnull() & df["SPP.Date"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Age.at.Hire, Title, Org.Date, Gender, SPP.Date, Salary, Start.Date, Pay.Grade, Employee.Status, Last.Name, Suffix.Name, First.Name, Middle.Initial]
# Index: []

# %%
df.loc[df["Start.Date"].isnull() & df["Org.Date"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Age.at.Hire, Title, Org.Date, Gender, SPP.Date, Salary, Start.Date, Pay.Grade, Employee.Status, Last.Name, Suffix.Name, First.Name, Middle.Initial]
# Index: []
