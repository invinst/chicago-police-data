# %%
import pandas as pd
import os
from AUIDFunctions import *

# %%
df = pd.read_csv("../input/salary.csv")
df.head()
# Out:
#    Year  Age.at.Hire           Title    Org.Date Gender    SPP.Date   Salary  \
# 0  2013         25.0  POLICE OFFICER  2016-06-16   MALE  1986-07-14  86130.0
# 1  2013         25.0  POLICE OFFICER  2014-03-17   MALE  2006-07-31  75372.0
# 2  2013         26.0  POLICE OFFICER  2013-12-03   MALE  2013-11-04  43104.0
# 3  2013         30.0  POLICE OFFICER  2013-12-02   MALE  2013-12-02  43104.0
# 4  2013         33.0  POLICE OFFICER  2013-12-02   MALE  2013-12-02  43104.0
#
#    Start.Date Pay.Grade              Employee.Status     Last.Name  \
# 0  1986-07-14       D|1               CAREER SERVICE        CLEARY
# 1  2006-07-31       D|1               CAREER SERVICE        LARSON
# 2  2013-11-04       D|1  PROBATIONARY CAREER SERVICE         ROSSI
# 3  2013-12-02       D|1  PROBATIONARY CAREER SERVICE         DORAN
# 4  2013-12-02       D|1  PROBATIONARY CAREER SERVICE  RAMAKRISHNAN
#
#   Suffix.Name First.Name Middle.Initial
# 0         NaN    MICHAEL              P
# ...

# %%
tdf = df.loc[df["Year"]==2002]

# %%
tdf
# Out:
#        Year  Age.at.Hire                                   Title    Org.Date  \
# 62756  2002         29.0                          POLICE OFFICER  1994-08-01
# 62757  2002         30.0                          POLICE OFFICER  1994-07-01
# 62758  2002         24.0                          POLICE OFFICER  1998-07-27
# 62759  2002         28.0                          POLICE OFFICER  1998-07-27
# 62760  2002         32.0                          POLICE OFFICER  1990-03-26
# 62761  2002         32.0                          POLICE OFFICER  2002-03-25
# 62762  2002          NaN  POLICE OFFICER (ASSIGNED AS DETECTIVE)  1969-04-19
# 62763  2002         42.0                          POLICE OFFICER  1992-12-07
# 62764  2002         29.0                          POLICE OFFICER  1999-10-25
# 62765  2002         35.0                          POLICE OFFICER  1981-04-13
# 62766  2002         25.0                          POLICE OFFICER  1994-08-01
# ...
