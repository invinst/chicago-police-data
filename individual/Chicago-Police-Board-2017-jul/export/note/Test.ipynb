# %%
import pandas as pd
full_df = pd.read_csv('../input/police-board.csv.gz')
acc_df = pd.read_csv('../input/accused.csv.gz')

# %%
full_df[((full_df['CRID'].notnull()) &
        (full_df['CRID'].isin(acc_df['CRID'])))|
        ((full_df['CRID2'].notnull()) &
        (full_df['CRID2'].isin(acc_df['CRID'])))]
# Out:
#            CRID  Filed.Date Ordered.Suspension.Month.  Case.NO  \
# 2408   259030.0  2000-03-14                       NaN     2409
# 2414   259785.0  2000-04-11                       NaN     2415
# 2420   260231.0  2000-05-03                       NaN     2421
# 2424   261457.0  2000-08-18                       NaN     2425
# 2425   260335.0  2000-08-18                        11     2426
# 2429   264460.0  2000-10-10                       NaN     2430
# 2431   261223.0  2000-10-24                       NaN     2432
# 2433   260833.0  2000-10-31                       NaN     2434
# 2434   264785.0  2000-11-09                       NaN     2435
# 2436   262494.0  2000-12-12                       NaN     2437
# 2446   259648.0  2001-02-22                       NaN     2447
# 2447   264152.0  2001-02-22                        18     2448
# 2448   259856.0  2001-03-13                        11     2449
# 2452   267058.0  2001-03-21                       NaN     2453
# ...
