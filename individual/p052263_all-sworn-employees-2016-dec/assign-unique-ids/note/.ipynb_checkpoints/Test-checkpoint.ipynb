# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv('../input/all-sworn.csv.gz')

# %%
print(df.shape)
df.head()
# Out:
# (32014, 8)
#   Appointed.Date      Race  Gender  Birth.Year Last.Name Suffix.Name  \
# 0     2005-09-26     WHITE    MALE        1971     AARON         NaN
# 1     2005-09-26  HISPANIC  FEMALE        1980     AARON         NaN
# 2     1970-06-15     WHITE    MALE        1942     ABATE         NaN
# 3     1994-12-05     WHITE    MALE        1968    ABBATE         NaN
# 4     1969-01-06     WHITE    MALE        1942    ABBATE         NaN
#
#   First.Name Middle.Initial
# 0    JEFFERY              M
# 1     KARINA            NaN
# 2     DANIEL              P
# 3    ANTHONY              G
# 4     CARMEL              G

# %%
# Are these guys unique?
id_cols = ["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name", "Appointed.Date", "Birth.Year", "Gender", "Race"]
keep_duplicates(df, id_cols)
# Out:
#       Appointed.Date      Race Gender  Birth.Year Last.Name Suffix.Name  \
# 24791     1999-06-21  HISPANIC   MALE        1968      ROMO         NaN
# 24792     1999-06-21  HISPANIC   MALE        1968      ROMO         NaN
# 4385      2000-01-24     BLACK   MALE        1972  CHAMBERS         NaN
# 4386      2000-01-24     BLACK   MALE        1972  CHAMBERS         NaN
# 27031     1971-02-22     WHITE   MALE        1947     SMITH         NaN
# 27032     1971-02-22     WHITE   MALE        1947     SMITH         NaN
# 29590     2005-12-05  HISPANIC   MALE        1981    VARGAS         NaN
# 29591     2005-12-05  HISPANIC   MALE        1981    VARGAS         NaN
# 15660     2003-09-29     WHITE   MALE        1976      LACZ         NaN
# 15661     2003-09-29     WHITE   MALE        1976      LACZ         NaN
#
#       First.Name Middle.Initial
# 24791      JORGE            NaN
# 24792      JORGE            NaN
# 4385        JOSE              A
# 4386        JOSE              A
# 27031     ROBERT              E
# 27032     ROBERT              E
# 29590     THOMAS            NaN
# 29591     THOMAS            NaN
# 15660   WOJCIECH            NaN
# 15661   WOJCIECH            NaN
