# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv('../input/trr-officers.csv.gz')
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        race gender  unit_detail assigned_beat  current_star in_uniform  unit  \
# 0  HISPANIC   MALE          NaN         1368A       21565.0         No    13
# 1  HISPANIC   MALE          NaN         1368A       17714.0         No    13
# 2  HISPANIC   MALE          NaN          1131       14214.0        Yes    11
# 3  HISPANIC   MALE          NaN          1131       11139.0        Yes    11
# 4     WHITE   MALE          NaN          1113       19364.0        Yes    11
#
#    age injured                  rank appointed_date  trr_id duty_status  \
# 0   36      No        POLICE OFFICER     1994-01-18       4         Yes
# 1   47     Yes        POLICE OFFICER     1985-11-18       5         Yes
# 2   26      No        POLICE OFFICER     2000-09-11       7         Yes
# 3   28     Yes        POLICE OFFICER     1999-10-25       8         Yes
# 4   33      No  LIEUTENANT OF POLICE     2001-09-04       9         Yes
#
# ...

# %%
df[df['middle_initial2'].notnull()][['middle_initial', 'middle_initial2']]
# Out:
#       middle_initial middle_initial2
# 8031               A               G
# 37955              A               G
# 47750              A               G
# 49235              A               G
# 51939              A               G
# 54355              A               G

# %%
dfu = df[['first_name', 'last_name', 'middle_initial', 'middle_initial2', 'suffix_name', 'first_name_NS',
          'last_name_NS','appointed_date', 'unit']].drop_duplicates()
id_cols = ['first_name_NS', 'last_name_NS', 'middle_initial', 'middle_initial2', 'suffix_name',
          'appointed_date']
keep_duplicates(dfu, id_cols)
# Out:
#       first_name   last_name middle_initial middle_initial2 suffix_name  \
# 35406      AARON     ACEVEDO            NaN             NaN         NaN
# 40947      AARON     ACEVEDO            NaN             NaN         NaN
# 12658      AARON    ARMSTEAD            NaN             NaN         NaN
# 18441      AARON    ARMSTEAD            NaN             NaN         NaN
# 22269      AARON    ARMSTEAD            NaN             NaN         NaN
# 58753      AARON       BURNS            NaN             NaN         NaN
# 65814      AARON       BURNS            NaN             NaN         NaN
# 20811      AARON    CHAPPELL            NaN             NaN         NaN
# 30542      AARON    CHAPPELL            NaN             NaN         NaN
# 41964      AARON    CHAPPELL            NaN             NaN         NaN
# 1100       AARON  CUNNINGHAM            NaN             NaN         NaN
# 39317      AARON  CUNNINGHAM            NaN             NaN         NaN
# ...

# %%
dfu = df[['first_name', 'last_name', 'middle_initial', 'middle_initial2', 'suffix_name', 'first_name_NS',
          'last_name_NS','appointed_date']].drop_duplicates()
id_cols = ['first_name_NS', 'last_name_NS', 'middle_initial', 'middle_initial2', 'suffix_name',
          'appointed_date']
keep_duplicates(dfu, id_cols)
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, middle_initial, middle_initial2, suffix_name, first_name_NS, last_name_NS, appointed_date]
# Index: []

# %%
dfu = df[['First.Name', 'Last.Name', 'Middle.Initial', 'Middle.Initial2', 'Suffix.Name', 'First.Name_NS',
          'Last.Name_NS','Appointed.Date', 'Gender', 'Race', 'Current.Star']].drop_duplicates()

# %%
dfu.shape
# Out:
# (10926, 11)

# %%
id_cols = ['First.Name_NS', 'Last.Name_NS', 'Middle.Initial', 'Suffix.Name',
          'Appointed.Date', 'Gender', 'Race', 'Current.Star']
keep_duplicates(dfu, id_cols)
# Out:
# Empty DataFrame
# Columns: [First.Name, Last.Name, Middle.Initial, Middle.Initial2, Suffix.Name, First.Name_NS, Last.Name_NS, Appointed.Date, Gender, Race, Current.Star]
# Index: []

# %%
id_cols = ['First.Name_NS', 'Last.Name_NS', 'Middle.Initial', 'Middle.Initial2', 'Suffix.Name',
          'Appointed.Date', 'Gender', 'Race']
keep_duplicates(dfu, id_cols)
# Out:
#       First.Name Last.Name Middle.Initial Middle.Initial2 Suffix.Name  \
# 484        DAVID     RAMOS            NaN             NaN         NaN
# 51482      DAVID     RAMOS            NaN             NaN         NaN
# 35312      JAMES   BANSLEY            NaN             NaN         NaN
# 37773      JAMES   BANSLEY            NaN             NaN         NaN
# 4424       KEVIN   CONNORS            NaN             NaN         NaN
# 15282      KEVIN   CONNORS            NaN             NaN         NaN
# 61755    RICARDO    TORRES            NaN             NaN         NaN
# 62542    RICARDO    TORRES            NaN             NaN         NaN
# 2677      ROBERT     SMITH            NaN             NaN         NaN
# 3854      ROBERT     SMITH            NaN             NaN         NaN
#
#       First.Name_NS Last.Name_NS Appointed.Date Gender      Race  Current.Star
# 484           DAVID        RAMOS     1994-07-05   MALE  HISPANIC        6737.0
# ...
