# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv('../input/trr-officers.csv.gz')

# %%
df.head()
# Out:
#   Injured Appointed.Date In.Uniform                  Rank  TRR.ID  Unit  \
# 0      No     1994-01-18         No        POLICE OFFICER       4    13
# 1     Yes     1985-11-18         No        POLICE OFFICER       5    13
# 2      No     2000-09-11        Yes        POLICE OFFICER       7    11
# 3     Yes     1999-10-25        Yes        POLICE OFFICER       8    11
# 4      No     2001-09-04        Yes  LIEUTENANT OF POLICE       9    11
#
#    Unit.Detail  Current.Age Assigned.Beat      Race Gender  Current.Star  \
# 0          NaN           36         1368A  HISPANIC   MALE         21565
# 1          NaN           47         1368A  HISPANIC   MALE         17714
# 2          NaN           26          1131  HISPANIC   MALE         14214
# 3          NaN           28          1131  HISPANIC   MALE         11139
# 4          NaN           33          1113     WHITE   MALE         19364
#
#   Duty.Status    Last.Name Suffix.Name First.Name  Middle.Initial
# ...

# %%
dfu = df[['First.Name', 'Last.Name', 'Middle.Initial', 'Suffix.Name',
          'Appointed.Date', 'Gender', 'Race', 'Current.Star', "Rank", "Current.Age"]].drop_duplicates()

# %%
dfu.shape
# Out:
# (38785, 10)

# %%
id_cols = ['First.Name', 'Last.Name', 'Middle.Initial', 'Suffix.Name',
          'Appointed.Date', 'Gender', 'Race', 'Current.Star']
keep_duplicates(dfu, id_cols)
# Out:
#       First.Name Last.Name  Middle.Initial Suffix.Name Appointed.Date  Gender  \
# 35406      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 36588      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 42001      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 47633      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 54099      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 58920      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 65798      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 12658      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 18441      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 22269      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 58753      AARON     BURNS             NaN         NaN     2013-06-03    MALE
# ...

# %%
id_cols = ['First.Name', 'Last.Name', 'Middle.Initial', 'Suffix.Name',
          'Appointed.Date', 'Gender', 'Race']
keep_duplicates(dfu, id_cols)
# Out:
#       First.Name Last.Name  Middle.Initial Suffix.Name Appointed.Date  Gender  \
# 35406      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 36588      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 42001      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 47633      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 54099      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 58920      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 65798      AARON   ACEVEDO             NaN         NaN     2009-12-16    MALE
# 12658      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 18441      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 22269      AARON  ARMSTEAD             NaN         NaN     2005-12-05    MALE
# 58753      AARON     BURNS             NaN         NaN     2013-06-03    MALE
# ...
