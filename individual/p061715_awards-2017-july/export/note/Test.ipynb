# %%
import pandas as pd

# %%
df = pd.read_csv('../input/awards.csv.gz')
df.columns
# Out:
# Index(['Gender', 'Race', 'Appointed.Date', 'Award.Type', 'Incident.Start.Date',
#        'Current.Award.Status', 'Award.Request.Date', 'Incident.End.Date',
#        'Resignation.Date', 'Award.ID', 'Current.Star', 'Rank', 'Birth.Year',
#        'Last.Promotion.Date', 'Requester.Full.Name', 'Ceremony.Date',
#        'Tracking.NO', 'Last.Name', 'Suffix.Name', 'First.Name',
#        'Middle.Initial', 'awards_ID'],
#       dtype='object')

# %%
ddf = pd.read_csv('../input/awards_demographics.csv.gz')

# %%
ddf.head()
# Out:
#    awards_ID First.Name Last.Name Appointed.Date  Gender  Birth.Year  \
# 0      10586    JEFFERY     AARON     2005-09-26    MALE        1971
# 1      13316     KARINA     AARON     2005-09-26  FEMALE        1980
# 2      23364      SUSAN     AARUP     2009-01-01  FEMALE        1969
# 3       1123    ANTHONY    ABBATE     1994-12-05    MALE        1968
# 4       2800     CARMEL    ABBATE     1969-01-06    MALE        1942
#
#    Current.Star
# 0          1424
# 1         20373
# 2          -999
# 3          -999
# 4          -999

# %%
ddf[ddf['Appointed.Date'].isnull()]
# Out:
#        awards_ID First.Name   Last.Name Appointed.Date   Gender  Birth.Year  \
# 578        23841     THOMAS     ANDREWS            NaN     MALE        1994
# 651        24751      TRENT       APPLE            NaN     MALE        1991
# 810        12389     JOSEPH     AUSMANN            NaN     MALE        1994
# 2559       25056    VINCENT       BROWN            NaN     MALE        1953
# 2985        2617    CAITLIN        CAIN            NaN   FEMALE        1994
# 3828       23489     SYSTEM       CHRIS            NaN  UNKNOWN        1950
# 5567       17078    MICHAEL      DEROSA            NaN     MALE        1993
# 8033       12521     JOSEPH      GAYDOS            NaN     MALE        1985
# 8209        4378     DANIEL   GILLESPIE            NaN     MALE        1994
# 9891       10739   JENNIFER   HERNANDEZ            NaN   FEMALE        1994
# 10025      22620    SHARELL       HICKS            NaN   FEMALE        1994
# ...

# %%
df[df['Appointed.Date'].isnull()]['Rank'].unique()
# Out:
# array(['4096-PROGRAM AIDE', 'UNK-UNKNOWN', '9161-POLICE OFFICER',
#        '0611-SYSTEMS PROGRAMMER'], dtype=object)
