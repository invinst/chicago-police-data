# %%
import pandas as pd
from assign_unique_ids_functions import *
import numpy as np

# %%
df = pd.read_csv('../input/awards.csv.gz')

# %%
df.head()
# Out:
#   Gender   Race Appointed.Date                          Award.Type  \
# 0   MALE  WHITE     2005-09-26  UNIT MERITORIOUS PERFORMANCE AWARD
# 1   MALE  WHITE     2005-09-26             DEPARTMENT COMMENDATION
# 2   MALE  WHITE     2005-09-26                   HONORABLE MENTION
# 3   MALE  WHITE     2005-09-26                   HONORABLE MENTION
# 4   MALE  WHITE     2005-09-26                   HONORABLE MENTION
#
#   Incident.Start.Date Current.Award.Status Award.Request.Date  \
# 0          2010-01-01               DENIED         2012-11-02
# 1          2014-06-27               DENIED         2014-06-29
# 2          2014-06-27               DENIED         2014-07-04
# 3          2006-05-11                FINAL         2006-06-07
# 4          2006-12-02                FINAL         2007-01-31
#
#   Incident.End.Date Resignation.Date  Award.ID      ...        \
# 0        2010-12-31              NaN    341867      ...
# 1        2014-06-27              NaN    632370      ...
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Race', 'Appointed.Date', 'Award.Type', 'Incident.Start.Date',
#        'Current.Award.Status', 'Award.Request.Date', 'Incident.End.Date',
#        'Resignation.Date', 'Award.ID', 'Current.Star', 'Rank', 'Birth.Year',
#        'Last.Promotion.Date', 'Requester.Full.Name', 'Ceremony.Date',
#        'Tracking.NO', 'Last.Name', 'Suffix.Name', 'First.Name',
#        'Middle.Initial'],
#       dtype='object')

# %%
dfu = df[["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name", "Resignation.Date", 
          "Race", "Gender", "Appointed.Date", "Rank", "Current.Star"]].drop_duplicates()

# %%
dfu.shape
# Out:
# (26135, 10)

# %%
dfu.head()
# Out:
#     First.Name Last.Name Middle.Initial Suffix.Name Resignation.Date  \
# 0      JEFFERY     AARON              M         NaN              NaN
# 82      KARINA     AARON            NaN         NaN              NaN
# 176      SUSAN     AARUP              J         NaN       2009-02-27
# 177    ANTHONY    ABBATE              G         NaN       2009-12-22
# 178     CARMEL    ABBATE              G         NaN       2003-08-15
#
#          Race  Gender Appointed.Date                     Rank  Current.Star
# 0       WHITE    MALE     2005-09-26  9171-SERGEANT OF POLICE          1424
# 82   HISPANIC  FEMALE     2005-09-26     9165-PO AS DETECTIVE         20373
# 176     WHITE  FEMALE     2009-01-01             0430-CLERK 3          -999
# 177     WHITE    MALE     1994-12-05      9161-POLICE OFFICER          -999
# 178     WHITE    MALE     1969-01-06     9165-PO AS DETECTIVE          -999

# %%
id_cols = ["First.Name", "Last.Name", "Appointed.Date", "Gender", "Suffix.Name"]
keep_duplicates(dfu, id_cols)
# Out:
#        First.Name     Last.Name Middle.Initial Suffix.Name Resignation.Date  \
# 214155        ANN          HERR              M         NaN       2010-06-16
# 214162        ANN          HERR              M         NaN              NaN
# 245404     AUDREY  JURCZYKOWSKI            NaN         NaN              NaN
# 245405     AUDREY  JURCZYKOWSKI              A         NaN              NaN
# 198893     BOBBIE          HALL            NaN         NaN       2006-07-09
# 198896     BOBBIE          HALL            NaN         NaN       2006-07-09
# 2276        DAVID        ADCOCK              G         NaN              NaN
# 2355        DAVID        ADCOCK              G         NaN              NaN
# 410543      DAVID         RAMOS            NaN         NaN       2009-10-21
# 410556      DAVID         RAMOS              R         NaN              NaN
# 550681      EDDIE     YOSHIMURA              M         NaN              NaN
# ...

# %%
df[(df['First.Name'] == 'AUDREY') & (df['Last.Name'] == 'JURCZYKOWSKI')]
# Out:
#         Gender   Race Appointed.Date                    Award.Type  \
# 245404  FEMALE  WHITE     1999-05-10  ATTENDANCE RECOGNITION AWARD
# 245405  FEMALE  WHITE     1999-05-10          COMPLIMENTARY LETTER
# 245406  FEMALE  WHITE     1999-05-10   2009 CRIME REDUCTION AWARD
# 245407  FEMALE  WHITE     1999-05-10          COMPLIMENTARY LETTER
# 245408  FEMALE  WHITE     1999-05-10             HONORABLE MENTION
# 245409  FEMALE  WHITE     1999-05-10          COMPLIMENTARY LETTER
# 245410  FEMALE  WHITE     1999-05-10  ATTENDANCE RECOGNITION AWARD
# 245411  FEMALE  WHITE     1999-05-10     NATO SUMMIT SERVICE AWARD
# 245412  FEMALE  WHITE     1999-05-10          COMPLIMENTARY LETTER
# 245413  FEMALE  WHITE     1999-05-10          SPECIAL COMMENDATION
# 245414  FEMALE  WHITE     1999-05-10             HONORABLE MENTION
#
#        Incident.Start.Date Current.Award.Status Award.Request.Date  \
# 245404          2004-01-01                FINAL         2009-08-01
# ...

# %%
id_cols = ["First.Name", "Last.Name", "Appointed.Date", "Gender", "Suffix.Name"]
kd = keep_duplicates(dfu, id_cols)
rd = remove_duplicates(dfu, id_cols)

# %%
kd = assign_unique_ids(kd, "tid",id_cols)

# %%
kdg = kd[list(set(kd.columns) - set(id_cols))].groupby('tid')

# %%
other_ids = ["Middle.Initial", "Resignation.Date", "Current.Star"]

# %%
def resolve_conflicts(group_df, compare_cols):
    out_df = pd.DataFrame()
    for key, group in group_df:
        conflicts = 0
        total_non_nan = 0
        for col in compare_cols:
            non_nan = group[col].dropna()
            non_nan = non_nan[non_nan != -999]
            total_non_nan += len(non_nan.unique())
            if len(non_nan.unique()) > 1:
                conflicts +=1
        if conflicts == 0 and total_non_nan > 0:
            group.insert(0, 'NID', group.index[0])
            # Not Different
        else:
            group.insert(0, 'NID', group.index)
            # Actually different
        out_df = out_df.append(group)
    return out_df

# %%
print(out_df.head(10))
# Out:
#    TID Resignation.Date Middle.Initial                      Rank      Race  \
# 0    0       2010-06-16              M       9111-CROSSING GUARD     WHITE
# 1    0              NaN              M               UNK-UNKNOWN     WHITE
# 2    2              NaN            NaN       9161-POLICE OFFICER     WHITE
# 3    2              NaN              A       9161-POLICE OFFICER     WHITE
# 4    4       2006-07-09            NaN       9111-CROSSING GUARD       API
# 5    4       2006-07-09            NaN       9111-CROSSING GUARD     BLACK
# 6    6              NaN              G  9164-PO/FIELD TRNING OFF     WHITE
# 7    6              NaN              G       9161-POLICE OFFICER     WHITE
# 8    8       2009-10-21            NaN       9161-POLICE OFFICER  HISPANIC
# 9    8              NaN              R       9161-POLICE OFFICER  HISPANIC
#
#    Current.Star  tid
# 0          -999    1
# 1          -999    1
# 2          -999    2
# 3          8280    2
# 4          -999    3
# ...

# %%
# Now create the full function

# %%
df.head()
# Out:
#   Gender   Race Appointed.Date                          Award.Type  \
# 0   MALE  WHITE     2005-09-26  UNIT MERITORIOUS PERFORMANCE AWARD
# 1   MALE  WHITE     2005-09-26             DEPARTMENT COMMENDATION
# 2   MALE  WHITE     2005-09-26                   HONORABLE MENTION
# 3   MALE  WHITE     2005-09-26                   HONORABLE MENTION
# 4   MALE  WHITE     2005-09-26                   HONORABLE MENTION
#
#   Incident.Start.Date Current.Award.Status Award.Request.Date  \
# 0          2010-01-01               DENIED         2012-11-02
# 1          2014-06-27               DENIED         2014-06-29
# 2          2014-06-27               DENIED         2014-07-04
# 3          2006-05-11                FINAL         2006-06-07
# 4          2006-12-02                FINAL         2007-01-31
#
#   Incident.End.Date Resignation.Date  Award.ID      ...        \
# 0        2010-12-31              NaN    341867      ...
# 1        2014-06-27              NaN    632370      ...
# ...

# %%
id_cols = ["First.Name", "Last.Name", "Appointed.Date", "Gender", "Suffix.Name"]
compare_cols = ["Middle.Initial", "Resignation.Date", "Current.Star"]
uid = 'awards_ID'

# %%
dfu = df[id_cols + compare_cols].drop_duplicates()
print(dfu.shape)
# Out:
# (26134, 8)

# %%
rd_df = remove_duplicates(dfu, id_cols)
rd_df.shape
# Out:
# (26094, 8)

# %%
kd_df = keep_duplicates(dfu, id_cols)
kd_df.shape
# Out:
# (40, 8)

# %%
kd_df = assign_unique_ids(kd_df, 'TID', id_cols)

# %%
kdg = kd_df[['TID'] + id_cols + compare_cols].groupby('TID', as_index=False)

# %%
rc = resolve_conflicts(kdg, compare_cols)

# %%
# Nope that won't work
