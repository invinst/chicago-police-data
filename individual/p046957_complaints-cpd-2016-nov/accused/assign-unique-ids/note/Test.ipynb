# %%
from assign_unique_ids_functions import *
import pandas as pd

# %%
df = pd.read_csv("../input/accused.csv.gz")
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfu = df[["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name", 
          "Appointed.Date", "Birth.Year", "Race", "Gender",
          "Current.Unit", "Current.Star", "Current.Rank"]].drop_duplicates()

# %%
id_cols = ["First.Name", "Last.Name", "Appointed.Date", "Race", "Gender"]
keep_duplicates(dfu, id_cols)
# Out:
#        First.Name  Last.Name Middle.Initial Suffix.Name Appointed.Date  \
# 1944        DAVID      RAMOS            NaN         NaN     1994-07-05
# 55891       DAVID      RAMOS            NaN         NaN     1994-07-05
# 96278       JAMES    BANSLEY            NaN         NaN     2009-12-16
# 100055      JAMES    BANSLEY            NaN         NaN     2009-12-16
# 6912         JOSE   CHAMBERS            NaN         NaN     2000-01-24
# 37058        JOSE   CHAMBERS            NaN         NaN     2000-01-24
# 314        JOSEPH    TRIPOLI            NaN         NaN     1994-07-05
# 16255      JOSEPH    TRIPOLI            NaN         NaN     1994-07-05
# 1707        KEVIN    CONNORS            NaN         NaN     1999-09-13
# 1747        KEVIN    CONNORS            NaN         NaN     1999-09-13
# 5790        KEVIN      SMITH            NaN         NaN     1999-05-10
# 18897       KEVIN      SMITH            NaN         NaN     1999-05-10
# 4572      MICHAEL  DOUGHERTY            NaN         NaN     1994-09-06
# 5600      MICHAEL  DOUGHERTY            NaN         NaN     1994-09-06
# 5064       ROBERT      SMITH            NaN         NaN     1996-12-02
# 7644       ROBERT      SMITH            NaN         NaN     1996-12-02
# 2021      TIMOTHY     OBRIEN              P         NaN     1995-01-03
# 2637      TIMOTHY     OBRIEN            NaN         NaN     1995-01-03
#
#         Birth.Year   Race Gender  Current.Unit  Current.Star Current.Rank
# 1944          1959  WHITE   MALE            14          -999           PO
# 55891         1969  WHITE   MALE            18          8560           PO
# 96278         1983  WHITE   MALE           193         10927           PO
# 100055        1983  WHITE   MALE             4          8791           PO
# 6912          1972  BLACK   MALE          -999          -999           PO
# 37058         1972  BLACK   MALE             2          4955           PO
# 314           1961  WHITE   MALE            25          -999           PO
# 16255         1968  WHITE   MALE           630         20571          DET
# 1707          1967  WHITE   MALE             7         15151           PO
# 1747          1975  WHITE   MALE           211          1182          SGT
# 5790          1964  BLACK   MALE           376          -999           PO
# 18897         1968  WHITE   MALE            25          -999           PO
# 4572          1963  WHITE   MALE            22          1635          SGT
# 5600          1965  WHITE   MALE            19          -999           PO
# 5064          1969  WHITE   MALE           610         20648          DET
# 7644          1972  WHITE   MALE           193         19314           PO
# 2021          1967  WHITE   MALE           630         20899          DET
# 2637          1967  WHITE   MALE           630         21797          DET

# %%
id_cols = ["First.Name", "Last.Name", "Appointed.Date", "Birth.Year", "Race", "Gender"]
keep_duplicates(dfu, id_cols)
# Out:
#        First.Name Last.Name Middle.Initial Suffix.Name Appointed.Date  \
# 96278       JAMES   BANSLEY            NaN         NaN     2009-12-16
# 100055      JAMES   BANSLEY            NaN         NaN     2009-12-16
# 6912         JOSE  CHAMBERS            NaN         NaN     2000-01-24
# 37058        JOSE  CHAMBERS            NaN         NaN     2000-01-24
# 2021      TIMOTHY    OBRIEN              P         NaN     1995-01-03
# 2637      TIMOTHY    OBRIEN            NaN         NaN     1995-01-03
#
#         Birth.Year   Race Gender  Current.Unit  Current.Star Current.Rank
# 96278         1983  WHITE   MALE           193         10927           PO
# 100055        1983  WHITE   MALE             4          8791           PO
# 6912          1972  BLACK   MALE          -999          -999           PO
# 37058         1972  BLACK   MALE             2          4955           PO
# 2021          1967  WHITE   MALE           630         20899          DET
# 2637          1967  WHITE   MALE           630         21797          DET
