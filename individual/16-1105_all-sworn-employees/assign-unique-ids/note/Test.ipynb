# %%
import pandas as pd
from assign_unique_ids_functions import *
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('../input/ase-units.csv.gz')
# Out:
# /Users/invinst/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['Current.Age.Decade'] = df['Current.Age'].map(lambda x: str(x)[0])

# %%
df.columns
# Out:
# Index(['Star9', 'Star1', 'Star10', 'Star6', 'Star5', 'Race', 'Star2',
#        'Current.Age', 'End.Date', 'Star7', 'Star4', 'Unit', 'Star3', 'Gender',
#        'Start.Date', 'Appointed.Date', 'Star8', 'First.Name', 'Last.Name',
#        'First.Name_NS', 'Last.Name_NS', 'Middle.Initial', 'Middle.Initial2',
#        'Suffix.Name', 'Current.Age.Decade'],
#       dtype='object')

# %%
stars = ["Star" + str(i) for i in range(1,11)]
dfu = df[["First.Name", "Last.Name", "Middle.Initial", "Suffix.Name",
          "Race", "Gender", "Current.Age", "Appointed.Date", 'Current.Age.Decade'] + stars].drop_duplicates()

# %%
keep_duplicates(dfu,["First.Name", "Last.Name", "Appointed.Date", "Current.Age"]).to_csv('UH_possible_duplicates.csv')

# %%
keep_duplicates(dfu,["First.Name", "Last.Name", "Appointed.Date", 'Current.Age.Decade'])
# Out:
#        First.Name     Last.Name Middle.Initial Suffix.Name      Race  Gender  \
# 53035      AUDREY  JURCZYKOWSKI            NaN         NaN     WHITE  FEMALE
# 53036      AUDREY  JURCZYKOWSKI            NaN         NaN     WHITE  FEMALE
# 107328      ERICK   VON KONDRAT            NaN         NaN     WHITE    MALE
# 107329      ERICK   VON KONDRAT            NaN         NaN     WHITE    MALE
# 52198      GEORGE         JONES            NaN         NaN     BLACK    MALE
# 52204      GEORGE         JONES            NaN         NaN     BLACK    MALE
# 5700        JAMES       BANSLEY            NaN         NaN     WHITE    MALE
# 5702        JAMES       BANSLEY            NaN         NaN     WHITE    MALE
# 76859       JAMES      O CONNOR            NaN         NaN     WHITE    MALE
# 76862       JAMES      O CONNOR            NaN         NaN     WHITE    MALE
# 99716       JAMES      STEPHENS            NaN         NaN     WHITE    MALE
# ...

# %%
df[(df['First.Name']=='ROBERT') & (df['Last.Name']=='SMITH')][[
    "First.Name", "Last.Name", "Appointed.Date", "Current.Age", "Star1", "Unit", "Start.Date","End.Date"]].sort_values('Current.Age')
# Out:
#       First.Name Last.Name Appointed.Date  Current.Age    Star1   Unit  \
# 97539     ROBERT     SMITH     1996-12-02         43.0  19314.0  193.0
# 97538     ROBERT     SMITH     1996-12-02         43.0  19314.0  153.0
# 97537     ROBERT     SMITH     1996-12-02         43.0  19314.0   44.0
# 97536     ROBERT     SMITH     1996-12-02         43.0  19314.0   25.0
# 97524     ROBERT     SMITH     1996-12-02         47.0  20648.0    9.0
# 97525     ROBERT     SMITH     1996-12-02         47.0  20648.0   23.0
# 97526     ROBERT     SMITH     1996-12-02         47.0  20648.0   44.0
# 97527     ROBERT     SMITH     1996-12-02         47.0  20648.0  610.0
# 97528     ROBERT     SMITH     1996-12-02         47.0  20648.0  640.0
# 97529     ROBERT     SMITH     1996-12-02         47.0  20648.0  715.0
# 97535     ROBERT     SMITH     1990-03-26         62.0   6900.0  715.0
# 97534     ROBERT     SMITH     1990-03-26         62.0   6900.0   44.0
# ...

# %%
kd = keep_duplicates(dfu,["First.Name", "Last.Name", "Appointed.Date", 'Current.Age'])

# %%
kd[kd['Middle.Initial2'].notnull()]
# Out:
# Empty DataFrame
# Columns: [First.Name, Last.Name, Middle.Initial, Middle.Initial2, Suffix.Name, Race, Gender, Current.Age, Appointed.Date, Star1, Star2, Star3, Star4, Star5, Star6, Star7, Star8, Star9, Star10]
# Index: []
