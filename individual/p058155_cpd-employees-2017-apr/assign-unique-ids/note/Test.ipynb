# %%
import pandas as pd
from assign_unique_ids_functions import *

# %%
df = pd.read_csv('../input/cpd-employees.csv.gz')

# %%
df.columns
# Out:
# Index(['Star2', 'Unit.Description', 'Current.Unit', 'Rank', 'Race', 'Star8',
#        'Appointed.Date', 'Star10', 'Star3', 'Star7', 'Star4', 'Star9',
#        'Gender', 'Current.Status', 'Resignation.Date', 'Birth.Year', 'Star1',
#        'Star6', 'Star5', 'Rank.Code', 'Current.Age', 'First.Name', 'Last.Name',
#        'Middle.Initial', 'Middle.Initial2', 'Suffix.Name'],
#       dtype='object')

# %%
df.shape
# Out:
# (32446, 26)

# %%
df['First.Name'].value_counts()
# Out:
# JOHN         1516
# JAMES        1244
# ROBERT       1180
# MICHAEL      1111
# WILLIAM       834
# THOMAS        823
# JOSEPH        757
# POLICE        649
# RICHARD       590
# DANIEL        463
# DAVID         463
# EDWARD        433
# ANTHONY       397
# CHARLES       361
# PATRICK       335
# GEORGE        322
# RONALD        311
# DONALD        294
# FRANK         279
# KENNETH       261
# RAYMOND       228
# PAUL          227
# KEVIN         226
# BRIAN         217
# MARK          212
# DENNIS        187
# TIMOTHY       185
# LAWRENCE      182
# STEVEN        179
# MATTHEW       170
#              ...
# MAZYAR          1
# WILHELMIN       1
# MELVILLE        1
# BRIEANN         1
# JARREDD         1
# SUMNER          1
# PHYLISS         1
# EDNALYN         1
# ADMIRA          1
# KAVORK          1
# MILLIE          1
# THERON          1
# TAMMRA          1
# EVELYNNA        1
# KRYSTYNA        1
# CONRAY          1
# ADOLPHO         1
# NIHAL           1
# CHUCK           1
# ...

# %%
keep_duplicates(df, 
                ['First.Name', 'Last.Name', 'Appointed.Date', 'Birth.Year', 'Gender', 'Race', 'Resignation.Date'])[
    ['First.Name', 'Last.Name','Middle.Initial', 'Suffix.Name',
                 'Middle.Initial2', 'Appointed.Date', 'Birth.Year',
     'Current.Age', 'Resignation.Date', 'Current.Unit', 'Star1', 'Star2']]
# Out:
#       First.Name     Last.Name Middle.Initial Suffix.Name Middle.Initial2  \
# 13947     AUDREY  JURCZYKOWSKI              A         NaN             NaN
# 13948     AUDREY  JURCZYKOWSKI            NaN         NaN             NaN
# 30367      ERICK    VONKONDRAT              M         NaN             NaN
# 30368      ERICK    VONKONDRAT            NaN         NaN             NaN
# 1261       JAMES       BANSLEY              A         NaN             NaN
# 1262       JAMES       BANSLEY              H         NaN             NaN
# 25259      JORGE          ROMO            NaN         NaN             NaN
# 25262      JORGE          ROMO            NaN         NaN             NaN
# 4386        JOSE      CHAMBERS              A         NaN             NaN
# 4387        JOSE      CHAMBERS              A         NaN             NaN
# 21814     POLICE       OFFICER            NaN         NaN             NaN
# 21840     POLICE       OFFICER            NaN         NaN             NaN
# ...
