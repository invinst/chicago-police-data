# %%
import pandas as pd
from assign_unique_ids_functions import *
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('../input/cpd-employees.csv.gz')

# %%
df.head()
# Out:
#      star2   star3 appointed_date resignation_date  star8  current_status  \
# 0   1424.0     NaN     2005-09-26              NaN    NaN               1
# 1  13705.0     NaN     2005-09-26              NaN    NaN               1
# 2   3023.0  2628.0     1970-06-15       2004-02-15    NaN               0
# 3      NaN     NaN     1969-01-06       2003-08-15    NaN               0
# 4      NaN     NaN     1954-10-16       1993-06-04    NaN               0
#
#    star5  star10      race    star1  current_unit rank_no        current_rank  \
# 0    NaN     NaN     WHITE  13001.0          16.0    9171  SERGEANT OF POLICE
# 1    NaN     NaN  HISPANIC  17545.0          15.0    9161      POLICE OFFICER
# 2    NaN     NaN     WHITE  14535.0         543.0    9161      POLICE OFFICER
# 3    NaN     NaN     WHITE  20484.0         640.0    9165     PO AS DETECTIVE
# 4    NaN     NaN     WHITE      NaN          25.0    9171  SERGEANT OF POLICE
#
# ...

# %%
df.columns
# Out:
# Index(['star2', 'star3', 'appointed_date', 'resignation_date', 'star8',
#        'current_status', 'star5', 'star10', 'race', 'star1', 'current_unit',
#        'rank_no', 'current_rank', 'birth_year', 'gender', 'current_age',
#        'unit_description', 'star9', 'star6', 'star7', 'star4', 'first_name',
#        'last_name_NS', 'first_name_NS', 'last_name', 'middle_initial',
#        'middle_initial2', 'suffix_name'],
#       dtype='object')

# %%
df[df['first_name'].isnull()]
# Out:
#        star2  star3 appointed_date resignation_date  star8  current_status  \
# 32445    NaN    NaN     1994-05-02              NaN    NaN               1
#
#        star5  star10   race  star1  current_unit rank_no    current_rank  \
# 32445    NaN     NaN  WHITE    NaN         542.0    9161  POLICE OFFICER
#
#        birth_year gender  current_age                        unit_description  \
# 32445      1969.0   MALE         47.0  DETACHED SERVICES - GOVERMENT SECURITY
#
#        star9  star6  star7  star4 first_name last_name_NS first_name_NS  \
# 32445    NaN    NaN    NaN    NaN        NaN          NaN           NaN
#
#       last_name middle_initial middle_initial2 suffix_name
# 32445       NaN              J             NaN         NaN

# %%
po_df = df[df['first_name']=='POLICE']
po_df.shape
# Out:
# (649, 28)

# %%
df = df[df['first_name']!='POLICE']
df.shape
# Out:
# (31797, 28)

# %%
df[(df['first_name'].isin(df[df['appointed_date'].isnull()]['first_name'])) & 
   (df['last_name'].isin(df[df['appointed_date'].isnull()]['last_name']))]
# Out:
#        star2  star3 appointed_date resignation_date  star8  current_status  \
# 3700     NaN    NaN            NaN              NaN    NaN               0
# 10988    NaN    NaN            NaN              NaN    NaN               0
# 13247    NaN    NaN            NaN              NaN    NaN               0
# 16565    NaN    NaN            NaN              NaN    NaN               0
# 25584    NaN    NaN            NaN              NaN    NaN               0
# 28312    NaN    NaN            NaN              NaN    NaN               0
#
#        star5  star10      race  star1  current_unit rank_no  \
# 3700     NaN     NaN       NaN    NaN           NaN     UNK
# 10988    NaN     NaN  HISPANIC    NaN           NaN     UNK
# 13247    NaN     NaN       NaN    NaN           NaN     UNK
# 16565    NaN     NaN  HISPANIC    NaN           NaN     UNK
# 25584    NaN     NaN     WHITE    NaN         112.0    9171
# 28312    NaN     NaN     WHITE    NaN           NaN     UNK
#
# ...

# %%
df[(df['first_name'].isin(df[df['birth_year'].isnull()]['first_name'])) & 
   (df['last_name'].isin(df[df['birth_year'].isnull()]['last_name']))]
# Out:
#         star2  star3 appointed_date resignation_date  star8  current_status  \
# 21997  1670.0  167.0     1991-10-16              NaN    NaN               1
# 25584     NaN    NaN            NaN              NaN    NaN               0
#
#        star5  star10   race    star1  current_unit rank_no  \
# 21997    NaN     NaN  WHITE  37907.0           NaN    9161
# 25584    NaN     NaN  WHITE      NaN         112.0    9171
#
#              current_rank  birth_year  gender  current_age  \
# 21997      POLICE OFFICER         NaN    MALE          NaN
# 25584  SERGEANT OF POLICE         NaN  FEMALE          NaN
#
#                        unit_description  star9  star6  star7  star4  \
# 21997                               NaN    NaN    NaN    NaN    NaN
# 25584  BUREAU OF PROFESSIONAL STANDARDS    NaN    NaN    NaN    NaN
#
#       first_name last_name_NS first_name_NS last_name middle_initial  \
# 21997     GEORGE     OPLAWSKI        GEORGE  OPLAWSKI              A
# ...

# %%
df[df['Middle.Initial2'].notnull()]
# Out:
# array(['R', 'G', 'M', 'J', 'P', 'W', 'S'], dtype=object)

# %%
id_cols =["first_name", "first_name_NS", "last_name", "last_name_NS", "appointed_date", "birth_year", "current_age"]
keep_duplicates(df, id_cols)[["first_name", "first_name_NS", "last_name", "last_name_NS","middle_initial", "middle_initial2", "suffix_name",
                              "appointed_date", "birth_year", "current_age", "current_rank", "resignation_date", "current_unit", "unit_description", "current_status", "star1", "star2"]]
# Out:
#       first_name first_name_NS     last_name  last_name_NS middle_initial  \
# 13947     AUDREY        AUDREY  JURCZYKOWSKI  JURCZYKOWSKI              A
# 13948     AUDREY        AUDREY  JURCZYKOWSKI  JURCZYKOWSKI            NaN
# 30367      ERICK         ERICK   VON KONDRAT    VONKONDRAT              M
# 30368      ERICK         ERICK   VON KONDRAT    VONKONDRAT            NaN
# 1807        JOEL          JOEL       BENTLEY       BENTLEY              A
# 1808        JOEL          JOEL       BENTLEY       BENTLEY              A
# 25259      JORGE         JORGE          ROMO          ROMO            NaN
# 25262      JORGE         JORGE          ROMO          ROMO            NaN
# 4386        JOSE          JOSE      CHAMBERS      CHAMBERS              A
# 4387        JOSE          JOSE      CHAMBERS      CHAMBERS              A
# 20185    STEPHEN       STEPHEN        MYTHEN        MYTHEN              C
# 20186    STEPHEN       STEPHEN        MYTHEN        MYTHEN            NaN
# ...

# %%
id_cols =["Appointed.Date", "Birth.Year", "Current.Age", "Current.Unit", "Star1", "Rank"]
keep_duplicates(po_df, id_cols)[["First.Name", "First.Name_NS", "Last.Name", "Last.Name_NS","Middle.Initial", "Middle.Initial2", "Suffix.Name", "Appointed.Date", "Birth.Year", "Current.Age", "Rank", "Resignation.Date", "Current.Unit", "Unit.Description", "Current.Status", "Star1", "Star2"]]
# Out:
#       First.Name First.Name_NS Last.Name Last.Name_NS Middle.Initial  \
# 21701     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21713     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21330     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21386     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21261     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21293     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21584     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21659     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21226     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21333     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21553     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21721     POLICE        POLICE   OFFICER      OFFICER            NaN
# 21648     POLICE        POLICE   OFFICER      OFFICER            NaN
# ...

# %%
df['Current.Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)
